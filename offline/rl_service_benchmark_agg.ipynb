# %% [markdown]
# # Benchmark for new DQN

# %%
import json
import math
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy

# Assuming these are in your local directory or environment
from scoring_service.HumanityScorer import scorer
from rl_service_offline_buffer_training import offline_rl_agent # Using the updated Balanced DQN Agent

# --- Configuration ---
DATA_DIR = "data"
MODEL_SAVE_PATH = "models/5/offline_rl_model_1_200.pt"

# %%
# Simulation Hyperparameters
TARGET_HUMAN_COUNT = 85
TARGET_BOT_COUNT = 200
SIMULATION_STEP_SECONDS = 10  # How often the RL agent is called (matches frontend)
SESSION_CHUNK_SIZE = int(SIMULATION_STEP_SECONDS * 1000)  # In milliseconds

conf = {
    "human": {"predicted": {"human": 0, "bot": 0}},
    "bot": {"predicted": {"human": 0, "bot": 0}}
}

# %%
def update_human_bot_population(human_count=None, bot_count=None):
    global TARGET_HUMAN_COUNT, TARGET_BOT_COUNT, conf
    TARGET_HUMAN_COUNT = random.randint(80, 100) if human_count is None else human_count
    TARGET_BOT_COUNT = random.choice([0, 20, 50, 100, 200, 1000]) if bot_count is None else bot_count
    
    # Reset Confusion Matrix for the new episode
    for key in ["human", "bot"]:
        for pred in ["human", "bot"]:
            conf[key]["predicted"][pred] = 0

def get_humanity_score(mouse_movement):
    if not mouse_movement:
        return None
    formatted_movements = [[m['x'], m['y']] for m in mouse_movement]
    try:
        # Assuming scorer is the LSTM model
        prediction = scorer.predict(formatted_movements)
        return float(prediction)
    except Exception as e:
        return 0.5

def calculate_reward(user, threat_level):
    """
    Refined reward function for balancing Security vs. UX.
    Weights are normalized so that one 'Happy Human' is roughly 
    equivalent to one 'Caught Bot'.
    """
    reward = 0
    done = False
    
    # Constants for tuning
    MAX_REWARD = 50.0        # Baseline for a 'Perfect' action
    LEAKAGE_PENALTY = -150.0 # Bot got through (Critical Failure)
    FRICTION_BASE = 2.0      # Sensitivity to human annoyance
    
    if user.is_bot:
        if threat_level > user.bot_strength:
            # Bot CAUGHT
            overkill = (threat_level - user.bot_strength)
            reward = MAX_REWARD - (overkill * 2.5) # Penalty for using high level on weak bot
            done = True
            user.reset_session()
        else:
            # Bot SURVIVED / LEAKED
            gap = user.bot_strength - threat_level
            reward = LEAKAGE_PENALTY - (gap * 5.0)
            user.captchas_solved += 1
    else:
        # HUMAN logic
        if threat_level == 0:
            reward = MAX_REWARD # Perfect score for zero friction
        else:
            # Level 1 is annoying, Level 10 is session-ending frustration
            frustration = math.pow(FRICTION_BASE, threat_level)
            reward = (MAX_REWARD / 2.0) - frustration
            
        user.captchas_solved += 1
        
        # Check if human gave up (Simulated patience)
        if threat_level == 10 or random.random() * (threat_level - 6) > 0.5:
            done = True # Human abandoned site due to high friction

    return reward, done


def load_session_data(data_dir):
    """Loads all human and bot raw data files."""
    human_sessions = []
    bot_sessions = []
    print(f"Loading raw session data from {data_dir}...")
    for filename in os.listdir(data_dir):
        if not filename.endswith('.json'): continue
        filepath = os.path.join(data_dir, filename)
        try:
            with open(filepath, 'r') as f:
                data = json.load(f)
            if filename.startswith('human'):
                human_sessions.append(data)
            elif filename.startswith('bot'):
                bot_sessions.append(data)
        except Exception as e:
            print(f"Warning: Could not load or parse {filename}. Error: {e}")

    print(f"Loaded {len(human_sessions)} human sessions and {len(bot_sessions)} bot sessions.")
    if not human_sessions or not bot_sessions:
        print("Error: Not enough data to run simulation. Please run bot simulator and browse site.")
        exit()
    return human_sessions, bot_sessions


def perturb_mouse_data(movements):
    """Creates a 'new' user by slightly altering existing mouse data."""
    if not movements: return []
    # Add small random noise to each coordinate
    noise_x = random.randint(-5//5, 5//5)
    noise_y = random.randint(-5//5, 5//5)
    return [{**m, 'x': m['x'] + noise_x, 'y': m['y'] + noise_y, 'timestamp': m['timestamp']} for m in movements]


def get_session_chunks(session_data, chunk_size_ms, target_chunks_size=12):
    """Splits a full session's mouse data into 10-second (step) chunks."""
    start_time = session_data['timestamps']['start']
    movements = session_data.get('mouse_movements', [])
    if not movements: return [[]]  # Return one empty chunk

    chunks = []
    current_chunk = []
    chunk_end_time = start_time + chunk_size_ms

    for move in movements:
        if move['timestamp'] <= chunk_end_time:
            current_chunk.append(move)
        else:
            chunks.append(current_chunk)
            if len(chunks) == target_chunks_size:
                return chunks
            # Handle multiple empty steps
            while move['timestamp'] > chunk_end_time + chunk_size_ms:
                chunks.append([])
                if len(chunks) == target_chunks_size:
                    return chunks
                chunk_end_time += chunk_size_ms

            current_chunk = [move]
            chunk_end_time += chunk_size_ms

    chunks.append(current_chunk)  # Add the last chunk
    if len(chunks) < target_chunks_size:
        chunks = chunks + get_session_chunks(session_data, chunk_size_ms, target_chunks_size=target_chunks_size - len(chunks))
    return chunks


# --- Simulation Classes ---

class SimulatedUser:
    def __init__(self, base_session_data, is_bot):
        self.is_bot = is_bot
        self.client_id = f"{'bot' if is_bot else 'human'}_{random.randint(10000, 99999)}"
        self.captchas_solved = 0
        self.last_captcha_solved = 0
        self.done = False
        self.last_humanity_score = 0.5
        self.average_humanity_score = 0.5
        self.n_humanity_score = 0
        self.bot_strength = random.randint(0, 9) if is_bot else None

        # Perturb and chunk the data to create a new, unique session
        perturbed_movements = perturb_mouse_data(base_session_data.get('mouse_movements', []))
        perturbed_session = {**base_session_data, 'mouse_movements': perturbed_movements}
        self.session_chunks = get_session_chunks(perturbed_session, SESSION_CHUNK_SIZE)
        self.current_chunk_index = 0

    def get_step_data(self):
        if self.current_chunk_index >= len(self.session_chunks):
            self.done = True
            return None
        chunk = self.session_chunks[self.current_chunk_index]
        self.current_chunk_index += 1
        return chunk
    
    def update_stats(self, h_score):
        if h_score is not None:
            self.last_humanity_score = h_score
            self.average_humanity_score = (self.average_humanity_score * self.n_humanity_score + h_score) / (self.n_humanity_score + 1)
            self.n_humanity_score += 1

    def reset_session(self):
        self.captchas_solved = 0
        self.done = True

# %%
# MODEL_SAVE_PATH = "models/5/offline_rl_model_1_200.pt"
MODEL_SAVE_PATH = "models/6/best_model_2_1.pt"
# MODEL_SAVE_PATH = "models/6/offline_rl_model_2_186.pt"

offline_rl_agent.load_model(MODEL_SAVE_PATH)
# Out:
# Loading offline model from models/6/best_model_2_1.pt...
# Offline model loaded successfully.

# %%
import random

bot_counts_lst = [0, 20, 100, 200, 500, 1000]
h_count = 100

SAMPLE_SIZE = 10

dct = dict()

for b_count in bot_counts_lst:
    update_human_bot_population(human_count=h_count, bot_count=b_count)

    for i in range(SAMPLE_SIZE):
        random.seed(i)

        # Track population over time
        human_counts = []
        bot_counts = []
        timestep_counts = []
        current_timestep = 0

        # This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
        pending_experiences = {}
        episode_reward = 0
        global_step_counter = 0
        episode_h_step_counter = 0
        episode_b_step_counter = 0
        episode_human_reward = 0
        episode_bot_reward = 0

        print("--- Starting Offline Training Simulator ---")
        base_human_sessions, base_bot_sessions = load_session_data(DATA_DIR)

        # update_human_bot_population(human_count=85, bot_count=200)

        # 1. Create the population for this episode
        print(f"Creating population: {TARGET_HUMAN_COUNT} humans, {TARGET_BOT_COUNT} bots")
        active_users = []
        for _ in range(TARGET_HUMAN_COUNT):
            active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
        for _ in range(TARGET_BOT_COUNT):
            active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))
            
        random.shuffle(active_users)

        human_count = TARGET_HUMAN_COUNT
        bot_count = TARGET_BOT_COUNT

        while active_users:
            # ---- Population tracking per timestep ----
            human_count = sum(1 for u in active_users if not u.is_bot)
            bot_count = sum(1 for u in active_users if u.is_bot)
            
            human_counts.append(human_count)
            bot_counts.append(bot_count)
            timestep_counts.append(current_timestep)
            current_timestep += 1
            
            server_total_users = len(active_users)
            server_req_rate_per_min = server_total_users * 7   # (random.randint(5, 15))

            next_active_users = []
            new_pending_experiences = {}

            for user in active_users:
                # 1. Get user's data and calculate current state s_t
                mouse_data = user.get_step_data()
                humanity_score = get_humanity_score(mouse_data)
                
                # if user.is_bot and humanity_score is not None:
                #     humanity_score = humanity_score ** 4
                    # print(humanity_score)

                user.update_stats(humanity_score)

                if humanity_score is None:
                    humanity_score = user.average_humanity_score

                conf["bot" if user.is_bot else "human"]["predicted"]["bot" if humanity_score >= .5 else "human"] += 1
                # print(user.is_bot, humanity_score)

                s_t = [
                    humanity_score,
                    user.average_humanity_score,
                    user.captchas_solved,
                    user.last_captcha_solved,   # client_req_rate_per_min, avg_h_score
                    # server_req_rate_per_min,
                    server_total_users
                ]

                # 2. Finalize the experience from step t-1
                if user.client_id in pending_experiences:
                    prev_s, prev_a, prev_r, prev_done = pending_experiences[user.client_id]
                    s_prime = s_t  # The current state is the "next_state" for the previous action

                    # Store the *completed* transition from t-1
                    # offline_rl_agent.remember(prev_s, prev_a, prev_r, s_prime, prev_done, user.is_bot)
                    episode_reward += prev_r

                # 3. Check if user's session ended *naturally* (ran out of data)
                if user.done:
                    continue  # User is done, no new action to take

                # 4. User is still active, take a new action (a_t)
                a_t = offline_rl_agent.select_action(s_t)
                
                # a_t = 10 if humanity_score > 0.5 else 0   
                # a_t = int(humanity_score * 10)

                # 5. Calculate reward (r_t) and if the action *caused* the session to end (done_t)
                r_t, done_t = calculate_reward(user, a_t)

                if user.is_bot:
                    episode_bot_reward += r_t
                    episode_b_step_counter += 1
                else:
                    episode_human_reward += r_t
                    episode_h_step_counter += 1
                    
                global_step_counter += 1

                # print(f"{'Bottt' if user.is_bot else 'Human'} -> action: {a_t}, reward {r_t}, done: {done_t}, score: {humanity_score}")

                # 6. Store this new experience
                if done_t:
                    # This is a terminal state (e.g., bot was killed).
                    # We have the full experience now. Store it immediately.
                    s_prime = s_t  # The 'next_state' is arbitrary, as 'done=True' nullifies it.
                    # offline_rl_agent.remember(s_t, a_t, r_t, s_prime, True, user.is_bot)
                    episode_reward += r_t
                    
                    # if user.is_bot:
                    #     bot_count -= 1
                    
                else:
                    # This is a non-terminal state.
                    # Store it as pending, waiting for s' from the next step.
                    new_pending_experiences[user.client_id] = (s_t, a_t, r_t, done_t)
                    user.last_captcha_solved = a_t
                    next_active_users.append(user)  # User continues

            
            if not next_active_users:
                print(f"Final remaining humans: {sum(1 for u in active_users if not u.is_bot)}")
                print(f"Final remaining bots: {sum(1 for u in active_users if u.is_bot)}")
                remaining_humans = sum(1 for u in active_users if not u.is_bot)
                remaining_bots = sum(1 for u in active_users if u.is_bot)

            # --- End of Step ---
            active_users = next_active_users
            pending_experiences = new_pending_experiences

            if not active_users:
                print(f"All users finished.")

        # Metrics logging...
        avg_rew = episode_reward / (episode_h_step_counter + episode_b_step_counter)   # (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_human_rew = episode_human_reward / episode_h_step_counter
        avg_bot_rew = episode_bot_reward / episode_b_step_counter if episode_b_step_counter else 0
        print(f"Total Reward: {episode_reward:.2f} | Avg: {avg_rew:.2f} | Avg Human: {avg_human_rew:.2f} | Avg Bot: {avg_bot_rew:.2f}")
            
        avg_session_rew = episode_reward / (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_h_session_rew = episode_human_reward / (TARGET_HUMAN_COUNT)
        avg_b_session_rew = episode_bot_reward / TARGET_BOT_COUNT if TARGET_BOT_COUNT else 0
        print(f"Average Session Rewards::: Mean: {avg_session_rew:.2f} | Human: {avg_h_session_rew:.2f} | Bot: {avg_b_session_rew:.2f}")

                
        print(f"Net reward: {episode_reward}")
        print(f"Normalized reward: {episode_reward / (TARGET_BOT_COUNT + TARGET_HUMAN_COUNT):0.2f}")
        print("Confusion Matrix:\n", conf)
        print("\n\n")

        dct[b_count] = {
            "session_rew": dct.get(b_count, {}).get("session_rew", []) + [avg_session_rew],
            "h_session_rew": dct.get(b_count, {}).get("h_session_rew", []) + [avg_h_session_rew],
            "b_session_rew": dct.get(b_count, {}).get("b_session_rew", []) + [avg_b_session_rew],
            "step_rew": dct.get(b_count, {}).get("step_rew", []) + [avg_rew],
            "h_step_rew": dct.get(b_count, {}).get("h_step_rew", []) + [avg_human_rew],
            "b_step_rew": dct.get(b_count, {}).get("b_step_rew", []) + [avg_bot_rew],
            "rem_h": dct.get(b_count, {}).get("rem_h", []) + [remaining_humans],
            "rem_b": dct.get(b_count, {}).get("rem_b", []) + [remaining_bots],
        }

with open("36_model_agg_evals/eval_dqn.json", "w") as f:
    json.dump(dct, f)
# Out:
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 82
# Final remaining bots: 0
# All users finished.
# Total Reward: 31442.00 | Avg: 30.23 | Avg Human: 30.23 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 314.42 | Human: 314.42 | Bot: 0.00
# Net reward: 31442.0
# Normalized reward: 314.42
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1029, 'bot': 93}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 80
# Final remaining bots: 0
# All users finished.
# Total Reward: 30457.00 | Avg: 29.37 | Avg Human: 29.37 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 304.57 | Human: 304.57 | Bot: 0.00
# Net reward: 30457.0
# Normalized reward: 304.57
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2039, 'bot': 200}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 73
# Final remaining bots: 0
# All users finished.
# Total Reward: 20007.00 | Avg: 20.48 | Avg Human: 20.48 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 200.07 | Human: 200.07 | Bot: 0.00
# Net reward: 20007.0
# Normalized reward: 200.07
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2961, 'bot': 328}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 84
# Final remaining bots: 0
# All users finished.
# Total Reward: 36023.00 | Avg: 33.29 | Avg Human: 33.29 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 360.23 | Human: 360.23 | Bot: 0.00
# Net reward: 36023.0
# Normalized reward: 360.23
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4036, 'bot': 419}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 78
# Final remaining bots: 0
# All users finished.
# Total Reward: 25677.00 | Avg: 25.55 | Avg Human: 25.55 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 256.77 | Human: 256.77 | Bot: 0.00
# Net reward: 25677.0
# Normalized reward: 256.77
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4994, 'bot': 544}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 82
# Final remaining bots: 0
# All users finished.
# Total Reward: 34232.00 | Avg: 32.45 | Avg Human: 32.45 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 342.32 | Human: 342.32 | Bot: 0.00
# Net reward: 34232.0
# Normalized reward: 342.32
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6036, 'bot': 639}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 75
# Final remaining bots: 0
# All users finished.
# Total Reward: 22974.00 | Avg: 22.84 | Avg Human: 22.84 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 229.74 | Human: 229.74 | Bot: 0.00
# Net reward: 22974.0
# Normalized reward: 229.74
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7022, 'bot': 734}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 74
# Final remaining bots: 0
# All users finished.
# Total Reward: 19275.00 | Avg: 19.83 | Avg Human: 19.83 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 192.75 | Human: 192.75 | Bot: 0.00
# Net reward: 19275.0
# Normalized reward: 192.75
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7954, 'bot': 848}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 74
# Final remaining bots: 0
# All users finished.
# Total Reward: 23322.00 | Avg: 23.14 | Avg Human: 23.14 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 233.22 | Human: 233.22 | Bot: 0.00
# Net reward: 23322.0
# Normalized reward: 233.22
# Confusion Matrix:
#  {'human': {'predicted': {'human': 8913, 'bot': 971}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 80
# Final remaining bots: 0
# All users finished.
# Total Reward: 27631.00 | Avg: 27.41 | Avg Human: 27.41 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 276.31 | Human: 276.31 | Bot: 0.00
# Net reward: 27631.0
# Normalized reward: 276.31
# Confusion Matrix:
#  {'human': {'predicted': {'human': 9883, 'bot': 1089}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 81
# Final remaining bots: 1
# All users finished.
# Total Reward: 27861.00 | Avg: 26.16 | Avg Human: 28.89 | Avg Bot: -56.47
# Average Session Rewards::: Mean: 232.18 | Human: 297.81 | Bot: -96.00
# Net reward: 27861.0
# Normalized reward: 232.18
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1019, 'bot': 93}}, 'bot': {'predicted': {'human': 16, 'bot': 19}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 68
#      65 for user in active_users:
#      66     # 1. Get user's data and calculate current state s_t
#      67     mouse_data = user.get_step_data()
# ---> 68     humanity_score = get_humanity_score(mouse_data)
#      70     # if user.is_bot and humanity_score is not None:
#      71     #     humanity_score = humanity_score ** 4
#      72         # print(humanity_score)
#      74     user.update_stats(humanity_score)
#
# Cell In[3], line 17, in get_humanity_score(mouse_movement)
#      14 formatted_movements = [[m['x'], m['y']] for m in mouse_movement]
#      15 try:
#      16     # Assuming scorer is the LSTM model
# ---> 17     prediction = scorer.predict(formatted_movements)
#      18     return float(prediction)
#      19 except Exception as e:
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\offline\scoring_service\HumanityScorer.py:34, in HumanityScorer.predict(self, mouse_movement)
#      32 data = [mouse_movement]
#      33 data = handle_data(data=data, max_length=CONTEXT_LENGTH)   # np.array(data).reshape((-1, 2))
# ---> 34 humanity_scores = self.model.predict(data, verbose=0)
#      35 humanity_scores = [score for [score] in humanity_scores]
#      36 # print(data.shape)
#      37 # print(humanity_scores)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:585, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     583 outputs = None
#     584 with epoch_iterator.catch_stop_iteration():
# --> 585     for begin_step, end_step, iterator in epoch_iterator:
#     586         callbacks.on_predict_batch_begin(begin_step)
#     587         data = get_data(iterator)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:764, in TFEpochIterator.__next__(self)
#     763 def __next__(self):
# --> 764     return next(self._epoch_iterator)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\trainers\epoch_iterator.py:125, in EpochIterator._enumerate_iterator(self)
#     119         yield (
#     120             step,
#     121             step + self.steps_per_execution - 1,
#     122             self._current_iterator,
#     123         )
#     124     if self._num_batches and self._steps_seen >= self._num_batches:
# --> 125         self._current_iterator = iter(self._get_iterator())
#     126         self._steps_seen = 0
#     127 else:
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))

plt.plot(timestep_counts, human_counts,
         label="Humans",
         linestyle="-",
         linewidth=2)

plt.plot(timestep_counts, bot_counts,
         label="Bots",
         linestyle="--",
         linewidth=2)

plt.xlabel("Timestep")
plt.ylabel("Number of Users")
plt.title("Human vs Bot Population Over Time")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import random

bot_counts_lst = [0, 20, 100, 200, 500, 1000]
h_count = 100

SAMPLE_SIZE = 10

dct = dict()

for b_count in bot_counts_lst:
    update_human_bot_population(human_count=h_count, bot_count=b_count)

    for i in range(SAMPLE_SIZE):
        random.seed(i)

        # Track population over time
        human_counts = []
        bot_counts = []
        timestep_counts = []
        current_timestep = 0

        # This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
        pending_experiences = {}
        episode_reward = 0
        global_step_counter = 0
        episode_h_step_counter = 0
        episode_b_step_counter = 0
        episode_human_reward = 0
        episode_bot_reward = 0

        print("--- Starting Offline Training Simulator ---")
        base_human_sessions, base_bot_sessions = load_session_data(DATA_DIR)

        # update_human_bot_population(human_count=85, bot_count=200)

        # 1. Create the population for this episode
        print(f"Creating population: {TARGET_HUMAN_COUNT} humans, {TARGET_BOT_COUNT} bots")
        active_users = []
        for _ in range(TARGET_HUMAN_COUNT):
            active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
        for _ in range(TARGET_BOT_COUNT):
            active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))
            
        random.shuffle(active_users)

        human_count = TARGET_HUMAN_COUNT
        bot_count = TARGET_BOT_COUNT

        while active_users:
            # ---- Population tracking per timestep ----
            human_count = sum(1 for u in active_users if not u.is_bot)
            bot_count = sum(1 for u in active_users if u.is_bot)
            
            human_counts.append(human_count)
            bot_counts.append(bot_count)
            timestep_counts.append(current_timestep)
            current_timestep += 1
            
            server_total_users = len(active_users)
            server_req_rate_per_min = server_total_users * 7   # (random.randint(5, 15))

            next_active_users = []
            new_pending_experiences = {}

            for user in active_users:
                # 1. Get user's data and calculate current state s_t
                mouse_data = user.get_step_data()
                humanity_score = get_humanity_score(mouse_data)
                
                # if user.is_bot and humanity_score is not None:
                #     humanity_score = humanity_score ** 4
                    # print(humanity_score)

                user.update_stats(humanity_score)

                if humanity_score is None:
                    humanity_score = user.average_humanity_score

                conf["bot" if user.is_bot else "human"]["predicted"]["bot" if humanity_score >= .5 else "human"] += 1
                # print(user.is_bot, humanity_score)

                s_t = [
                    humanity_score,
                    user.average_humanity_score,
                    user.captchas_solved,
                    user.last_captcha_solved,   # client_req_rate_per_min, avg_h_score
                    # server_req_rate_per_min,
                    server_total_users
                ]

                # 2. Finalize the experience from step t-1
                if user.client_id in pending_experiences:
                    prev_s, prev_a, prev_r, prev_done = pending_experiences[user.client_id]
                    s_prime = s_t  # The current state is the "next_state" for the previous action

                    # Store the *completed* transition from t-1
                    # offline_rl_agent.remember(prev_s, prev_a, prev_r, s_prime, prev_done, user.is_bot)
                    episode_reward += prev_r

                # 3. Check if user's session ended *naturally* (ran out of data)
                if user.done:
                    continue  # User is done, no new action to take

                # 4. User is still active, take a new action (a_t)
                a_t = 10 if humanity_score > 0.5 else 0   

                # 5. Calculate reward (r_t) and if the action *caused* the session to end (done_t)
                r_t, done_t = calculate_reward(user, a_t)

                if user.is_bot:
                    episode_bot_reward += r_t
                    episode_b_step_counter += 1
                else:
                    episode_human_reward += r_t
                    episode_h_step_counter += 1
                    
                global_step_counter += 1

                # print(f"{'Bottt' if user.is_bot else 'Human'} -> action: {a_t}, reward {r_t}, done: {done_t}, score: {humanity_score}")

                # 6. Store this new experience
                if done_t:
                    # This is a terminal state (e.g., bot was killed).
                    # We have the full experience now. Store it immediately.
                    s_prime = s_t  # The 'next_state' is arbitrary, as 'done=True' nullifies it.
                    # offline_rl_agent.remember(s_t, a_t, r_t, s_prime, True, user.is_bot)
                    episode_reward += r_t
                    
                    # if user.is_bot:
                    #     bot_count -= 1
                    
                else:
                    # This is a non-terminal state.
                    # Store it as pending, waiting for s' from the next step.
                    new_pending_experiences[user.client_id] = (s_t, a_t, r_t, done_t)
                    user.last_captcha_solved = a_t
                    next_active_users.append(user)  # User continues

            
            if not next_active_users:
                print(f"Final remaining humans: {sum(1 for u in active_users if not u.is_bot)}")
                print(f"Final remaining bots: {sum(1 for u in active_users if u.is_bot)}")
                remaining_humans = sum(1 for u in active_users if not u.is_bot)
                remaining_bots = sum(1 for u in active_users if u.is_bot)

            # --- End of Step ---
            active_users = next_active_users
            pending_experiences = new_pending_experiences

            if not active_users:
                print(f"All users finished.")

        # Metrics logging...
        avg_rew = episode_reward / (episode_h_step_counter + episode_b_step_counter)   # (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_human_rew = episode_human_reward / episode_h_step_counter
        avg_bot_rew = episode_bot_reward / episode_b_step_counter if episode_b_step_counter else 0
        print(f"Total Reward: {episode_reward:.2f} | Avg: {avg_rew:.2f} | Avg Human: {avg_human_rew:.2f} | Avg Bot: {avg_bot_rew:.2f}")
            
        avg_session_rew = episode_reward / (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_h_session_rew = episode_human_reward / (TARGET_HUMAN_COUNT)
        avg_b_session_rew = episode_bot_reward / TARGET_BOT_COUNT if TARGET_BOT_COUNT else 0
        print(f"Average Session Rewards::: Mean: {avg_session_rew:.2f} | Human: {avg_h_session_rew:.2f} | Bot: {avg_b_session_rew:.2f}")

                
        print(f"Net reward: {episode_reward}")
        print(f"Normalized reward: {episode_reward / (TARGET_BOT_COUNT + TARGET_HUMAN_COUNT):0.2f}")
        print("Confusion Matrix:\n", conf)
        print("\n\n")

        dct[b_count] = {
            "session_rew": dct.get(b_count, {}).get("session_rew", []) + [avg_session_rew],
            "h_session_rew": dct.get(b_count, {}).get("h_session_rew", []) + [avg_h_session_rew],
            "b_session_rew": dct.get(b_count, {}).get("b_session_rew", []) + [avg_b_session_rew],
            "step_rew": dct.get(b_count, {}).get("step_rew", []) + [avg_rew],
            "h_step_rew": dct.get(b_count, {}).get("h_step_rew", []) + [avg_human_rew],
            "b_step_rew": dct.get(b_count, {}).get("b_step_rew", []) + [avg_bot_rew],
            "rem_h": dct.get(b_count, {}).get("rem_h", []) + [remaining_humans],
            "rem_b": dct.get(b_count, {}).get("rem_b", []) + [remaining_bots],
        }

with open("36_model_agg_evals/eval_static_threshold.json", "w") as f:
    json.dump(dct, f)
# Out:
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 62
# Final remaining bots: 0
# All users finished.
# Total Reward: 7788.00 | Avg: 8.17 | Avg Human: 8.17 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 77.88 | Human: 77.88 | Bot: 0.00
# Net reward: 7788.0
# Normalized reward: 77.88
# Confusion Matrix:
#  {'human': {'predicted': {'human': 943, 'bot': 72}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 57
# Final remaining bots: 0
# All users finished.
# Total Reward: 1393.00 | Avg: 1.50 | Avg Human: 1.50 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 13.93 | Human: 13.93 | Bot: 0.00
# Net reward: 1393.0
# Normalized reward: 13.93
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1847, 'bot': 155}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 53
# Final remaining bots: 0
# All users finished.
# Total Reward: -5603.00 | Avg: -6.41 | Avg Human: -6.41 | Avg Bot: 0.00
# Average Session Rewards::: Mean: -56.03 | Human: -56.03 | Bot: 0.00
# Net reward: -5603.0
# Normalized reward: -56.03
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2661, 'bot': 268}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 69
# Final remaining bots: 0
# All users finished.
# Total Reward: 17131.00 | Avg: 17.25 | Avg Human: 17.25 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 171.31 | Human: 171.31 | Bot: 0.00
# Net reward: 17131.0
# Normalized reward: 171.31
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3656, 'bot': 335}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 47
# Final remaining bots: 0
# All users finished.
# Total Reward: -12747.00 | Avg: -14.87 | Avg Human: -14.87 | Avg Bot: 0.00
# Average Session Rewards::: Mean: -127.47 | Human: -127.47 | Bot: 0.00
# Net reward: -12747.0
# Normalized reward: -127.47
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4457, 'bot': 438}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 59
# Final remaining bots: 0
# All users finished.
# Total Reward: 2891.00 | Avg: 3.15 | Avg Human: 3.15 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 28.91 | Human: 28.91 | Bot: 0.00
# Net reward: 2891.0
# Normalized reward: 28.91
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5364, 'bot': 508}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 59
# Final remaining bots: 0
# All users finished.
# Total Reward: 3741.00 | Avg: 4.00 | Avg Human: 4.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 37.41 | Human: 37.41 | Bot: 0.00
# Net reward: 3741.0
# Normalized reward: 37.41
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6277, 'bot': 589}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 50
# Final remaining bots: 0
# All users finished.
# Total Reward: -10200.00 | Avg: -12.07 | Avg Human: -12.07 | Avg Bot: 0.00
# Average Session Rewards::: Mean: -102.00 | Human: -102.00 | Bot: 0.00
# Net reward: -10200.0
# Normalized reward: -102.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7071, 'bot': 690}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 47
# Final remaining bots: 0
# All users finished.
# Total Reward: -12097.00 | Avg: -13.90 | Avg Human: -13.90 | Avg Bot: 0.00
# Average Session Rewards::: Mean: -120.97 | Human: -120.97 | Bot: 0.00
# Net reward: -12097.0
# Normalized reward: -120.97
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7889, 'bot': 789}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 51
# Final remaining bots: 0
# All users finished.
# Total Reward: -7301.00 | Avg: -8.28 | Avg Human: -8.28 | Avg Bot: 0.00
# Average Session Rewards::: Mean: -73.01 | Human: -73.01 | Bot: 0.00
# Net reward: -7301.0
# Normalized reward: -73.01
# Confusion Matrix:
#  {'human': {'predicted': {'human': 8728, 'bot': 883}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 62
# Final remaining bots: 1
# All users finished.
# Total Reward: 5688.00 | Avg: 5.76 | Avg Human: 8.17 | Avg Bot: -60.00
# Average Session Rewards::: Mean: 47.40 | Human: 77.88 | Bot: -105.00
# Net reward: 5688.0
# Normalized reward: 47.40
# Confusion Matrix:
#  {'human': {'predicted': {'human': 943, 'bot': 72}}, 'bot': {'predicted': {'human': 16, 'bot': 20}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 57
# Final remaining bots: 1
# All users finished.
# Total Reward: -497.00 | Avg: -0.52 | Avg Human: 1.50 | Avg Bot: -54.00
# Average Session Rewards::: Mean: -4.14 | Human: 13.93 | Bot: -94.50
# Net reward: -497.0
# Normalized reward: -4.14
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1847, 'bot': 155}}, 'bot': {'predicted': {'human': 32, 'bot': 40}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 53
# Final remaining bots: 3
# All users finished.
# Total Reward: -11793.00 | Avg: -12.65 | Avg Human: -6.41 | Avg Bot: -106.72
# Average Session Rewards::: Mean: -98.28 | Human: -56.03 | Bot: -309.50
# Net reward: -11793.0
# Normalized reward: -98.28
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2661, 'bot': 268}}, 'bot': {'predicted': {'human': 74, 'bot': 59}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 69
# Final remaining bots: 4
# All users finished.
# Total Reward: 9003.50 | Avg: 8.50 | Avg Human: 17.25 | Avg Bot: -123.14
# Average Session Rewards::: Mean: 75.03 | Human: 171.31 | Bot: -406.38
# Net reward: 9003.5
# Normalized reward: 75.03
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3656, 'bot': 335}}, 'bot': {'predicted': {'human': 127, 'bot': 76}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 47
# Final remaining bots: 2
# All users finished.
# Total Reward: -16874.50 | Avg: -18.73 | Avg Human: -14.87 | Avg Bot: -93.81
# Average Session Rewards::: Mean: -140.62 | Human: -127.47 | Bot: -206.38
# Net reward: -16874.5
# Normalized reward: -140.62
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4457, 'bot': 438}}, 'bot': {'predicted': {'human': 154, 'bot': 95}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 59
# Final remaining bots: 3
# All users finished.
# Total Reward: -3416.50 | Avg: -3.50 | Avg Human: 3.15 | Avg Bot: -110.66
# Average Session Rewards::: Mean: -28.47 | Human: 28.91 | Bot: -315.38
# Net reward: -3416.5
# Normalized reward: -28.47
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5364, 'bot': 508}}, 'bot': {'predicted': {'human': 197, 'bot': 112}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 59
# Final remaining bots: 2
# All users finished.
# Total Reward: -666.50 | Avg: -0.68 | Avg Human: 4.00 | Avg Bot: -95.82
# Average Session Rewards::: Mean: -5.55 | Human: 37.41 | Bot: -220.38
# Net reward: -666.5
# Normalized reward: -5.55
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6277, 'bot': 589}}, 'bot': {'predicted': {'human': 226, 'bot': 131}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 50
# Final remaining bots: 1
# All users finished.
# Total Reward: -11980.00 | Avg: -13.63 | Avg Human: -12.07 | Avg Bot: -52.35
# Average Session Rewards::: Mean: -99.83 | Human: -102.00 | Bot: -89.00
# Net reward: -11980.0
# Normalized reward: -99.83
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7071, 'bot': 690}}, 'bot': {'predicted': {'human': 242, 'bot': 150}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 47
# Final remaining bots: 1
# All users finished.
# Total Reward: -13857.00 | Avg: -15.33 | Avg Human: -13.90 | Avg Bot: -51.76
# Average Session Rewards::: Mean: -115.47 | Human: -120.97 | Bot: -88.00
# Net reward: -13857.0
# Normalized reward: -115.47
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7889, 'bot': 789}}, 'bot': {'predicted': {'human': 258, 'bot': 169}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 51
# Final remaining bots: 3
# All users finished.
# Total Reward: -13996.00 | Avg: -14.91 | Avg Human: -8.28 | Avg Bot: -117.46
# Average Session Rewards::: Mean: -116.63 | Human: -73.01 | Bot: -334.75
# Net reward: -13996.0
# Normalized reward: -116.63
# Confusion Matrix:
#  {'human': {'predicted': {'human': 8728, 'bot': 883}}, 'bot': {'predicted': {'human': 301, 'bot': 186}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 62
# Final remaining bots: 9
# All users finished.
# Total Reward: -11077.00 | Avg: -9.43 | Avg Human: 8.17 | Avg Bot: -84.98
# Average Session Rewards::: Mean: -55.38 | Human: 77.88 | Bot: -188.65
# Net reward: -11077.0
# Normalized reward: -55.38
# Confusion Matrix:
#  {'human': {'predicted': {'human': 943, 'bot': 72}}, 'bot': {'predicted': {'human': 133, 'bot': 98}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 57
# Final remaining bots: 8
# All users finished.
# Total Reward: -15277.00 | Avg: -13.39 | Avg Human: 1.50 | Avg Bot: -79.00
# Average Session Rewards::: Mean: -76.39 | Human: 13.93 | Bot: -166.70
# Net reward: -15277.0
# Normalized reward: -76.39
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1847, 'bot': 155}}, 'bot': {'predicted': {'human': 256, 'bot': 194}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 53
# Final remaining bots: 7
# All users finished.
# Total Reward: -19560.50 | Avg: -18.30 | Avg Human: -6.41 | Avg Bot: -71.58
# Average Session Rewards::: Mean: -97.80 | Human: -56.03 | Bot: -139.57
# Net reward: -19560.5
# Normalized reward: -97.80
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2661, 'bot': 268}}, 'bot': {'predicted': {'human': 360, 'bot': 292}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 69
# Final remaining bots: 12
# All users finished.
# Total Reward: -8689.00 | Avg: -6.97 | Avg Human: 17.25 | Avg Bot: -102.06
# Average Session Rewards::: Mean: -43.45 | Human: 171.31 | Bot: -258.20
# Net reward: -8689.0
# Normalized reward: -43.45
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3656, 'bot': 335}}, 'bot': {'predicted': {'human': 534, 'bot': 383}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 47
# Final remaining bots: 7
# All users finished.
# Total Reward: -28914.50 | Avg: -27.28 | Avg Human: -14.87 | Avg Bot: -79.64
# Average Session Rewards::: Mean: -144.57 | Human: -127.47 | Bot: -161.68
# Net reward: -28914.5
# Normalized reward: -144.57
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4457, 'bot': 438}}, 'bot': {'predicted': {'human': 644, 'bot': 483}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 59
# Final remaining bots: 8
# All users finished.
# Total Reward: -14141.50 | Avg: -12.54 | Avg Human: 3.15 | Avg Bot: -81.11
# Average Session Rewards::: Mean: -70.71 | Human: 28.91 | Bot: -170.32
# Net reward: -14141.5
# Normalized reward: -70.71
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5364, 'bot': 508}}, 'bot': {'predicted': {'human': 766, 'bot': 579}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 59
# Final remaining bots: 9
# All users finished.
# Total Reward: -15214.00 | Avg: -13.21 | Avg Human: 4.00 | Avg Bot: -87.35
# Average Session Rewards::: Mean: -76.07 | Human: 37.41 | Bot: -189.55
# Net reward: -15214.0
# Normalized reward: -76.07
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6277, 'bot': 589}}, 'bot': {'predicted': {'human': 898, 'bot': 673}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 50
# Final remaining bots: 9
# All users finished.
# Total Reward: -28830.00 | Avg: -27.17 | Avg Human: -12.07 | Avg Bot: -86.25
# Average Session Rewards::: Mean: -144.15 | Human: -102.00 | Bot: -186.30
# Net reward: -28830.0
# Normalized reward: -144.15
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7071, 'bot': 690}}, 'bot': {'predicted': {'human': 1025, 'bot': 771}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 47
# Final remaining bots: 9
# All users finished.
# Total Reward: -30582.00 | Avg: -28.01 | Avg Human: -13.90 | Avg Bot: -83.27
# Average Session Rewards::: Mean: -152.91 | Human: -120.97 | Bot: -184.85
# Net reward: -30582.0
# Normalized reward: -152.91
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7889, 'bot': 789}}, 'bot': {'predicted': {'human': 1164, 'bot': 863}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 51
# Final remaining bots: 13
# All users finished.
# Total Reward: -35711.00 | Avg: -31.16 | Avg Human: -8.28 | Avg Bot: -107.61
# Average Session Rewards::: Mean: -178.56 | Human: -73.01 | Bot: -284.10
# Net reward: -35711.0
# Normalized reward: -178.56
# Confusion Matrix:
#  {'human': {'predicted': {'human': 8728, 'bot': 883}}, 'bot': {'predicted': {'human': 1351, 'bot': 953}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 62
# Final remaining bots: 24
# All users finished.
# Total Reward: -43389.50 | Avg: -29.58 | Avg Human: 8.17 | Avg Bot: -99.57
# Average Session Rewards::: Mean: -144.63 | Human: 77.88 | Bot: -255.89
# Net reward: -43389.5
# Normalized reward: -144.63
# Confusion Matrix:
#  {'human': {'predicted': {'human': 943, 'bot': 72}}, 'bot': {'predicted': {'human': 349, 'bot': 189}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 57
# Final remaining bots: 15
# All users finished.
# Total Reward: -30147.00 | Avg: -22.48 | Avg Human: 1.50 | Avg Bot: -76.74
# Average Session Rewards::: Mean: -100.49 | Human: 13.93 | Bot: -157.70
# Net reward: -30147.0
# Normalized reward: -100.49
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1847, 'bot': 155}}, 'bot': {'predicted': {'human': 577, 'bot': 387}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 53
# Final remaining bots: 22
# All users finished.
# Total Reward: -49748.00 | Avg: -36.91 | Avg Human: -6.41 | Avg Bot: -93.13
# Average Session Rewards::: Mean: -165.83 | Human: -56.03 | Bot: -220.72
# Net reward: -49748.0
# Normalized reward: -165.83
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2661, 'bot': 268}}, 'bot': {'predicted': {'human': 884, 'bot': 576}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 69
# Final remaining bots: 23
# All users finished.
# Total Reward: -30736.50 | Avg: -20.73 | Avg Human: 17.25 | Avg Bot: -97.69
# Average Session Rewards::: Mean: -102.45 | Human: 171.31 | Bot: -239.34
# Net reward: -30736.5
# Normalized reward: -102.45
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3656, 'bot': 335}}, 'bot': {'predicted': {'human': 1211, 'bot': 762}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 47
# Final remaining bots: 13
# All users finished.
# Total Reward: -43277.00 | Avg: -34.48 | Avg Human: -14.87 | Avg Bot: -76.71
# Average Session Rewards::: Mean: -144.26 | Human: -127.47 | Bot: -152.65
# Net reward: -43277.0
# Normalized reward: -144.26
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4457, 'bot': 438}}, 'bot': {'predicted': {'human': 1422, 'bot': 962}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 59
# Final remaining bots: 21
# All users finished.
# Total Reward: -40254.00 | Avg: -28.90 | Avg Human: 3.15 | Avg Bot: -90.83
# Average Session Rewards::: Mean: -134.18 | Human: 28.91 | Bot: -215.72
# Net reward: -40254.0
# Normalized reward: -134.18
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5364, 'bot': 508}}, 'bot': {'predicted': {'human': 1729, 'bot': 1151}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 59
# Final remaining bots: 22
# All users finished.
# Total Reward: -41109.00 | Avg: -29.16 | Avg Human: 4.00 | Avg Bot: -94.42
# Average Session Rewards::: Mean: -137.03 | Human: 37.41 | Bot: -224.25
# Net reward: -41109.0
# Normalized reward: -137.03
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6277, 'bot': 589}}, 'bot': {'predicted': {'human': 2043, 'bot': 1334}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 50
# Final remaining bots: 15
# All users finished.
# Total Reward: -42465.00 | Avg: -33.94 | Avg Human: -12.07 | Avg Bot: -79.47
# Average Session Rewards::: Mean: -141.55 | Human: -102.00 | Bot: -161.32
# Net reward: -42465.0
# Normalized reward: -141.55
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7071, 'bot': 690}}, 'bot': {'predicted': {'human': 2266, 'bot': 1532}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 47
# Final remaining bots: 18
# All users finished.
# Total Reward: -50177.00 | Avg: -38.19 | Avg Human: -13.90 | Avg Bot: -85.77
# Average Session Rewards::: Mean: -167.26 | Human: -120.97 | Bot: -190.40
# Net reward: -50177.0
# Normalized reward: -167.26
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7889, 'bot': 789}}, 'bot': {'predicted': {'human': 2537, 'bot': 1723}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 51
# Final remaining bots: 21
# All users finished.
# Total Reward: -53558.50 | Avg: -39.35 | Avg Human: -8.28 | Avg Bot: -96.57
# Average Session Rewards::: Mean: -178.53 | Human: -73.01 | Bot: -231.29
# Net reward: -53558.5
# Normalized reward: -178.53
# Confusion Matrix:
#  {'human': {'predicted': {'human': 8728, 'bot': 883}}, 'bot': {'predicted': {'human': 2852, 'bot': 1908}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 62
# Final remaining bots: 48
# All users finished.
# Total Reward: -95062.00 | Avg: -45.25 | Avg Human: 8.17 | Avg Bot: -89.59
# Average Session Rewards::: Mean: -158.44 | Human: 77.88 | Bot: -205.70
# Net reward: -95062.0
# Normalized reward: -158.44
# Confusion Matrix:
#  {'human': {'predicted': {'human': 943, 'bot': 72}}, 'bot': {'predicted': {'human': 711, 'bot': 485}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 57
# Final remaining bots: 53
# All users finished.
# Total Reward: -112502.00 | Avg: -52.99 | Avg Human: 1.50 | Avg Bot: -95.44
# Average Session Rewards::: Mean: -187.50 | Human: 13.93 | Bot: -227.71
# Net reward: -112502.0
# Normalized reward: -187.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1847, 'bot': 155}}, 'bot': {'predicted': {'human': 1485, 'bot': 957}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 53
# Final remaining bots: 49
# All users finished.
# Total Reward: -105333.00 | Avg: -52.67 | Avg Human: -6.41 | Avg Bot: -88.57
# Average Session Rewards::: Mean: -175.56 | Human: -56.03 | Bot: -199.46
# Net reward: -105333.0
# Normalized reward: -175.56
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2661, 'bot': 268}}, 'bot': {'predicted': {'human': 2185, 'bot': 1432}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 69
# Final remaining bots: 60
# All users finished.
# Total Reward: -106164.00 | Avg: -47.39 | Avg Human: 17.25 | Avg Bot: -98.87
# Average Session Rewards::: Mean: -176.94 | Human: 171.31 | Bot: -246.59
# Net reward: -106164.0
# Normalized reward: -176.94
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3656, 'bot': 335}}, 'bot': {'predicted': {'human': 3036, 'bot': 1888}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 47
# Final remaining bots: 53
# All users finished.
# Total Reward: -127144.50 | Avg: -61.75 | Avg Human: -14.87 | Avg Bot: -95.17
# Average Session Rewards::: Mean: -211.91 | Human: -127.47 | Bot: -228.79
# Net reward: -127144.5
# Normalized reward: -211.91
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4457, 'bot': 438}}, 'bot': {'predicted': {'human': 3813, 'bot': 2366}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 59
# Final remaining bots: 47
# All users finished.
# Total Reward: -94466.50 | Avg: -46.33 | Avg Human: 3.15 | Avg Bot: -86.85
# Average Session Rewards::: Mean: -157.44 | Human: 28.91 | Bot: -194.72
# Net reward: -94466.5
# Normalized reward: -157.44
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5364, 'bot': 508}}, 'bot': {'predicted': {'human': 4507, 'bot': 2840}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 59
# Final remaining bots: 43
# All users finished.
# Total Reward: -84139.00 | Avg: -42.11 | Avg Human: 4.00 | Avg Bot: -82.67
# Average Session Rewards::: Mean: -140.23 | Human: 37.41 | Bot: -175.76
# Net reward: -84139.0
# Normalized reward: -140.23
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6277, 'bot': 589}}, 'bot': {'predicted': {'human': 5135, 'bot': 3318}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import random

bot_counts_lst = [0, 20, 100, 200, 500, 1000]
h_count = 100

SAMPLE_SIZE = 10

dct = dict()

for b_count in bot_counts_lst:
    update_human_bot_population(human_count=h_count, bot_count=b_count)

    for i in range(SAMPLE_SIZE):
        random.seed(i)

        # Track population over time
        human_counts = []
        bot_counts = []
        timestep_counts = []
        current_timestep = 0

        # This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
        pending_experiences = {}
        episode_reward = 0
        global_step_counter = 0
        episode_h_step_counter = 0
        episode_b_step_counter = 0
        episode_human_reward = 0
        episode_bot_reward = 0

        print("--- Starting Offline Training Simulator ---")
        base_human_sessions, base_bot_sessions = load_session_data(DATA_DIR)

        # update_human_bot_population(human_count=85, bot_count=200)

        # 1. Create the population for this episode
        print(f"Creating population: {TARGET_HUMAN_COUNT} humans, {TARGET_BOT_COUNT} bots")
        active_users = []
        for _ in range(TARGET_HUMAN_COUNT):
            active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
        for _ in range(TARGET_BOT_COUNT):
            active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))
            
        random.shuffle(active_users)

        human_count = TARGET_HUMAN_COUNT
        bot_count = TARGET_BOT_COUNT

        while active_users:
            # ---- Population tracking per timestep ----
            human_count = sum(1 for u in active_users if not u.is_bot)
            bot_count = sum(1 for u in active_users if u.is_bot)
            
            human_counts.append(human_count)
            bot_counts.append(bot_count)
            timestep_counts.append(current_timestep)
            current_timestep += 1
            
            server_total_users = len(active_users)
            server_req_rate_per_min = server_total_users * 7   # (random.randint(5, 15))

            next_active_users = []
            new_pending_experiences = {}

            for user in active_users:
                # 1. Get user's data and calculate current state s_t
                mouse_data = user.get_step_data()
                humanity_score = get_humanity_score(mouse_data)
                
                # if user.is_bot and humanity_score is not None:
                #     humanity_score = humanity_score ** 4
                    # print(humanity_score)

                user.update_stats(humanity_score)

                if humanity_score is None:
                    humanity_score = user.average_humanity_score

                conf["bot" if user.is_bot else "human"]["predicted"]["bot" if humanity_score >= .5 else "human"] += 1
                # print(user.is_bot, humanity_score)

                s_t = [
                    humanity_score,
                    user.average_humanity_score,
                    user.captchas_solved,
                    user.last_captcha_solved,   # client_req_rate_per_min, avg_h_score
                    # server_req_rate_per_min,
                    server_total_users
                ]

                # 2. Finalize the experience from step t-1
                if user.client_id in pending_experiences:
                    prev_s, prev_a, prev_r, prev_done = pending_experiences[user.client_id]
                    s_prime = s_t  # The current state is the "next_state" for the previous action

                    # Store the *completed* transition from t-1
                    # offline_rl_agent.remember(prev_s, prev_a, prev_r, s_prime, prev_done, user.is_bot)
                    episode_reward += prev_r

                # 3. Check if user's session ended *naturally* (ran out of data)
                if user.done:
                    continue  # User is done, no new action to take

                # 4. User is still active, take a new action (a_t)
                a_t = int(humanity_score * 10)

                # 5. Calculate reward (r_t) and if the action *caused* the session to end (done_t)
                r_t, done_t = calculate_reward(user, a_t)

                if user.is_bot:
                    episode_bot_reward += r_t
                    episode_b_step_counter += 1
                else:
                    episode_human_reward += r_t
                    episode_h_step_counter += 1
                    
                global_step_counter += 1

                # print(f"{'Bottt' if user.is_bot else 'Human'} -> action: {a_t}, reward {r_t}, done: {done_t}, score: {humanity_score}")

                # 6. Store this new experience
                if done_t:
                    # This is a terminal state (e.g., bot was killed).
                    # We have the full experience now. Store it immediately.
                    s_prime = s_t  # The 'next_state' is arbitrary, as 'done=True' nullifies it.
                    # offline_rl_agent.remember(s_t, a_t, r_t, s_prime, True, user.is_bot)
                    episode_reward += r_t
                    
                    # if user.is_bot:
                    #     bot_count -= 1
                    
                else:
                    # This is a non-terminal state.
                    # Store it as pending, waiting for s' from the next step.
                    new_pending_experiences[user.client_id] = (s_t, a_t, r_t, done_t)
                    user.last_captcha_solved = a_t
                    next_active_users.append(user)  # User continues

            
            if not next_active_users:
                print(f"Final remaining humans: {sum(1 for u in active_users if not u.is_bot)}")
                print(f"Final remaining bots: {sum(1 for u in active_users if u.is_bot)}")
                remaining_humans = sum(1 for u in active_users if not u.is_bot)
                remaining_bots = sum(1 for u in active_users if u.is_bot)

            # --- End of Step ---
            active_users = next_active_users
            pending_experiences = new_pending_experiences

            if not active_users:
                print(f"All users finished.")

        # Metrics logging...
        avg_rew = episode_reward / (episode_h_step_counter + episode_b_step_counter)   # (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_human_rew = episode_human_reward / episode_h_step_counter
        avg_bot_rew = episode_bot_reward / episode_b_step_counter if episode_b_step_counter else 0
        print(f"Total Reward: {episode_reward:.2f} | Avg: {avg_rew:.2f} | Avg Human: {avg_human_rew:.2f} | Avg Bot: {avg_bot_rew:.2f}")
            
        avg_session_rew = episode_reward / (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_h_session_rew = episode_human_reward / (TARGET_HUMAN_COUNT)
        avg_b_session_rew = episode_bot_reward / TARGET_BOT_COUNT if TARGET_BOT_COUNT else 0
        print(f"Average Session Rewards::: Mean: {avg_session_rew:.2f} | Human: {avg_h_session_rew:.2f} | Bot: {avg_b_session_rew:.2f}")

                
        print(f"Net reward: {episode_reward}")
        print(f"Normalized reward: {episode_reward / (TARGET_BOT_COUNT + TARGET_HUMAN_COUNT):0.2f}")
        print("Confusion Matrix:\n", conf)
        print("\n\n")

        dct[b_count] = {
            "session_rew": dct.get(b_count, {}).get("session_rew", []) + [avg_session_rew],
            "h_session_rew": dct.get(b_count, {}).get("h_session_rew", []) + [avg_h_session_rew],
            "b_session_rew": dct.get(b_count, {}).get("b_session_rew", []) + [avg_b_session_rew],
            "step_rew": dct.get(b_count, {}).get("step_rew", []) + [avg_rew],
            "h_step_rew": dct.get(b_count, {}).get("h_step_rew", []) + [avg_human_rew],
            "b_step_rew": dct.get(b_count, {}).get("b_step_rew", []) + [avg_bot_rew],
            "rem_h": dct.get(b_count, {}).get("rem_h", []) + [remaining_humans],
            "rem_b": dct.get(b_count, {}).get("rem_b", []) + [remaining_bots],
        }

with open("36_model_agg_evals/eval_static_tiers.json", "w") as f:
    json.dump(dct, f)
# Out:
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 51
# Final remaining bots: 0
# All users finished.
# Total Reward: -8001.00 | Avg: -9.22 | Avg Human: -9.22 | Avg Bot: 0.00
# Average Session Rewards::: Mean: -80.01 | Human: -80.01 | Bot: 0.00
# Net reward: -8001.0
# Normalized reward: -80.01
# Confusion Matrix:
#  {'human': {'predicted': {'human': 819, 'bot': 100}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 58
# Final remaining bots: 1
# All users finished.
# Total Reward: -60.50 | Avg: -0.06 | Avg Human: 1.90 | Avg Bot: -54.62
# Average Session Rewards::: Mean: -0.50 | Human: 17.42 | Bot: -90.12
# Net reward: -60.5
# Normalized reward: -0.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 875, 'bot': 99}}, 'bot': {'predicted': {'human': 14, 'bot': 20}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 49
# Final remaining bots: 8
# All users finished.
# Total Reward: -28979.00 | Avg: -27.60 | Avg Human: -13.61 | Avg Bot: -83.88
# Average Session Rewards::: Mean: -144.90 | Human: -114.49 | Bot: -175.30
# Net reward: -28979.0
# Normalized reward: -144.90
# Confusion Matrix:
#  {'human': {'predicted': {'human': 784, 'bot': 106}}, 'bot': {'predicted': {'human': 120, 'bot': 97}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 53
# Final remaining bots: 15
# All users finished.
# Total Reward: -37408.00 | Avg: -28.60 | Avg Human: -4.96 | Avg Bot: -80.18
# Average Session Rewards::: Mean: -124.69 | Human: -44.53 | Bot: -164.78
# Net reward: -37408.0
# Normalized reward: -124.69
# Confusion Matrix:
#  {'human': {'predicted': {'human': 828, 'bot': 122}}, 'bot': {'predicted': {'human': 232, 'bot': 194}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 51
# Final remaining bots: 44
# All users finished.
# Total Reward: -99491.00 | Avg: -51.63 | Avg Human: -10.97 | Avg Bot: -83.25
# Average Session Rewards::: Mean: -165.82 | Human: -92.51 | Bot: -180.48
# Net reward: -99491.0
# Normalized reward: -165.82
# Confusion Matrix:
#  {'human': {'predicted': {'human': 780, 'bot': 114}}, 'bot': {'predicted': {'human': 645, 'bot': 483}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 1000 bots
# Final remaining humans: 52
# Final remaining bots: 98
# All users finished.
# Total Reward: -213499.50 | Avg: -67.27 | Avg Human: -7.28 | Avg Bot: -90.24
# Average Session Rewards::: Mean: -194.09 | Human: -64.02 | Bot: -207.10
# Net reward: -213499.5
# Normalized reward: -194.09
# Confusion Matrix:
#  {'human': {'predicted': {'human': 836, 'bot': 95}}, 'bot': {'predicted': {'human': 1453, 'bot': 940}}}

# %%
import json

bot_counts_lst = [0, 20, 100, 200, 500, 1000]
h_count = 100

dct = dict()

for b_count in bot_counts_lst:
    update_human_bot_population(human_count=h_count, bot_count=b_count)

    # Track population over time
    human_counts = []
    bot_counts = []
    timestep_counts = []
    current_timestep = 0

    # This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
    pending_experiences = {}
    episode_reward = 0
    global_step_counter = 0
    episode_h_step_counter = 0
    episode_b_step_counter = 0
    episode_human_reward = 0
    episode_bot_reward = 0

    print("--- Starting Offline Training Simulator ---")
    base_human_sessions, base_bot_sessions = load_session_data(DATA_DIR)

    # 1. Create the population for this episode
    print(f"Creating population: {TARGET_HUMAN_COUNT} humans, {TARGET_BOT_COUNT} bots")
    active_users = []
    for _ in range(TARGET_HUMAN_COUNT):
        active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
    for _ in range(TARGET_BOT_COUNT):
        active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))
        
    random.shuffle(active_users)

    human_count = TARGET_HUMAN_COUNT
    bot_count = TARGET_BOT_COUNT

    while active_users:
        # ---- Population tracking per timestep ----
        human_count = sum(1 for u in active_users if not u.is_bot)
        bot_count = sum(1 for u in active_users if u.is_bot)
        
        human_counts.append(human_count)
        bot_counts.append(bot_count)
        timestep_counts.append(current_timestep)
        current_timestep += 1
        
        server_total_users = len(active_users)
        server_req_rate_per_min = server_total_users * 7   # (random.randint(5, 15))

        next_active_users = []
        new_pending_experiences = {}

        for user in active_users:
            # 1. Get user's data and calculate current state s_t
            mouse_data = user.get_step_data()
            humanity_score = get_humanity_score(mouse_data)
            
            # if user.is_bot and humanity_score is not None:
            #     humanity_score = humanity_score ** 4
                # print(humanity_score)

            user.update_stats(humanity_score)

            if humanity_score is None:
                humanity_score = user.average_humanity_score

            conf["bot" if user.is_bot else "human"]["predicted"]["bot" if humanity_score >= .5 else "human"] += 1
            # print(user.is_bot, humanity_score)

            s_t = [
                humanity_score,
                user.average_humanity_score,
                user.captchas_solved,
                user.last_captcha_solved,   # client_req_rate_per_min, avg_h_score
                # server_req_rate_per_min,
                server_total_users
            ]

            # 2. Finalize the experience from step t-1
            if user.client_id in pending_experiences:
                prev_s, prev_a, prev_r, prev_done = pending_experiences[user.client_id]
                s_prime = s_t  # The current state is the "next_state" for the previous action

                # Store the *completed* transition from t-1
                # offline_rl_agent.remember(prev_s, prev_a, prev_r, s_prime, prev_done, user.is_bot)
                episode_reward += prev_r

            # 3. Check if user's session ended *naturally* (ran out of data)
            if user.done:
                continue  # User is done, no new action to take

            # 4. User is still active, take a new action (a_t)
            # a_t = offline_rl_agent.select_action(s_t)
            
            # a_t = 10 if humanity_score > 0.5 else 0   
            a_t = int(humanity_score * 10)

            # 5. Calculate reward (r_t) and if the action *caused* the session to end (done_t)
            r_t, done_t = calculate_reward(user, a_t)

            if user.is_bot:
                episode_bot_reward += r_t
                episode_b_step_counter += 1
            else:
                episode_human_reward += r_t
                episode_h_step_counter += 1

            global_step_counter += 1

            # print(f"{'Bottt' if user.is_bot else 'Human'} -> action: {a_t}, reward {r_t}, done: {done_t}, score: {humanity_score}")

            # 6. Store this new experience
            if done_t:
                # This is a terminal state (e.g., bot was killed).
                # We have the full experience now. Store it immediately.
                s_prime = s_t  # The 'next_state' is arbitrary, as 'done=True' nullifies it.
                # offline_rl_agent.remember(s_t, a_t, r_t, s_prime, True, user.is_bot)
                episode_reward += r_t
                
                # if user.is_bot:
                #     bot_count -= 1
                
            else:
                # This is a non-terminal state.
                # Store it as pending, waiting for s' from the next step.
                new_pending_experiences[user.client_id] = (s_t, a_t, r_t, done_t)
                user.last_captcha_solved = a_t
                next_active_users.append(user)  # User continues

        if not next_active_users:
            print(f"Final remaining humans: {sum(1 for u in active_users if not u.is_bot)}")
            print(f"Final remaining bots: {sum(1 for u in active_users if u.is_bot)}")

        # --- End of Step ---
        active_users = next_active_users
        pending_experiences = new_pending_experiences

        if not active_users:
            print(f"All users finished.")

    # Metrics logging...
    avg_rew = episode_reward / (episode_h_step_counter + episode_b_step_counter)   # (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
    avg_human_rew = episode_human_reward / episode_h_step_counter
    avg_bot_rew = episode_bot_reward / episode_b_step_counter if episode_b_step_counter else 0
    print(f"Total Reward: {episode_reward:.2f} | Avg: {avg_rew:.2f} | Avg Human: {avg_human_rew:.2f} | Avg Bot: {avg_bot_rew:.2f}")
        
    avg_session_rew = episode_reward / (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
    avg_h_session_rew = episode_human_reward / (TARGET_HUMAN_COUNT)
    avg_b_session_rew = episode_bot_reward / TARGET_BOT_COUNT if TARGET_BOT_COUNT else 0
    print(f"Average Session Rewards::: Mean: {avg_session_rew:.2f} | Human: {avg_h_session_rew:.2f} | Bot: {avg_b_session_rew:.2f}")
            
    print(f"Net reward: {episode_reward}")
    print(f"Normalized reward: {episode_reward / (TARGET_BOT_COUNT + TARGET_HUMAN_COUNT):0.2f}")
    print("Confusion Matrix:\n", conf)
    print("\n\n")

    dct[b_count] = {
        "timesteps": timestep_counts,
        "human_counts": human_counts,
        "bot_counts": bot_counts
    }

with open("eval_static_tiers.json", "w") as f:
    json.dump(dct, f)
# Out:
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 0 bots
# Final remaining humans: 69
# Final remaining bots: 0
# All users finished.
# Total Reward: 21776.00 | Avg: 20.88 | Avg Human: 20.88 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 217.76 | Human: 217.76 | Bot: 0.00
# Net reward: 21776.0
# Normalized reward: 217.76
# Confusion Matrix:
#  {'human': {'predicted': {'human': 954, 'bot': 158}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 20 bots
# Final remaining humans: 65
# Final remaining bots: 1
# All users finished.
# Total Reward: 17422.00 | Avg: 16.44 | Avg Human: 19.31 | Avg Bot: -60.79
# Average Session Rewards::: Mean: 145.18 | Human: 197.32 | Bot: -115.50
# Net reward: 17422.0
# Normalized reward: 145.18
# Confusion Matrix:
#  {'human': {'predicted': {'human': 951, 'bot': 136}}, 'bot': {'predicted': {'human': 8, 'bot': 31}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 100 bots
# Final remaining humans: 69
# Final remaining bots: 15
# All users finished.
# Total Reward: -7106.00 | Avg: -5.35 | Avg Human: 20.60 | Avg Bot: -101.67
# Average Session Rewards::: Mean: -35.53 | Human: 215.23 | Bot: -286.70
# Net reward: -7106.0
# Normalized reward: -35.53
# Confusion Matrix:
#  {'human': {'predicted': {'human': 965, 'bot': 149}}, 'bot': {'predicted': {'human': 103, 'bot': 194}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 200 bots
# Final remaining humans: 70
# Final remaining bots: 41
# All users finished.
# Total Reward: -57712.50 | Avg: -33.63 | Avg Human: 22.32 | Avg Bot: -117.03
# Average Session Rewards::: Mean: -192.38 | Human: 229.20 | Bot: -403.16
# Net reward: -57712.5
# Normalized reward: -192.38
# Confusion Matrix:
#  {'human': {'predicted': {'human': 964, 'bot': 133}}, 'bot': {'predicted': {'human': 339, 'bot': 391}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 500 bots
# Final remaining humans: 68
# Final remaining bots: 79
# All users finished.
# Total Reward: -133344.00 | Avg: -53.42 | Avg Human: 22.43 | Avg Bot: -105.93
# Average Session Rewards::: Mean: -222.24 | Human: 228.96 | Bot: -312.48
# Net reward: -133344.0
# Normalized reward: -222.24
# Confusion Matrix:
#  {'human': {'predicted': {'human': 973, 'bot': 116}}, 'bot': {'predicted': {'human': 572, 'bot': 982}}}
#
#
#
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 100 humans, 1000 bots
# Final remaining humans: 65
# Final remaining bots: 170
# All users finished.
# Total Reward: -313194.50 | Avg: -76.41 | Avg Human: 21.82 | Avg Bot: -109.12
# Average Session Rewards::: Mean: -284.72 | Human: 223.88 | Bot: -335.31
# Net reward: -313194.5
# Normalized reward: -284.72
# Confusion Matrix:
#  {'human': {'predicted': {'human': 971, 'bot': 120}}, 'bot': {'predicted': {'human': 1458, 'bot': 1785}}}

# %%
# Track population over time
human_counts = []
bot_counts = []
timestep_counts = []
current_timestep = 0

# This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
pending_experiences = {}
episode_reward = 0

print("--- Starting Offline Training Simulator ---")
base_human_sessions, base_bot_sessions = load_session_data(DATA_DIR)

update_human_bot_population(human_count=85, bot_count=1000)

# 1. Create the population for this episode
print(f"Creating population: {TARGET_HUMAN_COUNT} humans, {TARGET_BOT_COUNT} bots")
active_users = []
for _ in range(TARGET_HUMAN_COUNT):
    active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
for _ in range(TARGET_BOT_COUNT):
    active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))
    
random.shuffle(active_users)

human_count = TARGET_HUMAN_COUNT
bot_count = TARGET_BOT_COUNT

while active_users:
    # ---- Population tracking per timestep ----
    human_count = sum(1 for u in active_users if not u.is_bot)
    bot_count = sum(1 for u in active_users if u.is_bot)
    
    human_counts.append(human_count)
    bot_counts.append(bot_count)
    timestep_counts.append(current_timestep)
    current_timestep += 1
    
    server_total_users = len(active_users)
    server_req_rate_per_min = server_total_users * 7   # (random.randint(5, 15))

    next_active_users = []
    new_pending_experiences = {}

    for user in active_users:
        # 1. Get user's data and calculate current state s_t
        mouse_data = user.get_step_data()
        humanity_score = get_humanity_score(mouse_data)
        
        # if user.is_bot and humanity_score is not None:
        #     humanity_score = humanity_score ** 4
            # print(humanity_score)

        user.update_stats(humanity_score)

        if humanity_score is None:
            humanity_score = user.average_humanity_score

        conf["bot" if user.is_bot else "human"]["predicted"]["bot" if humanity_score >= .5 else "human"] += 1
        # print(user.is_bot, humanity_score)

        s_t = [
            humanity_score,
            user.average_humanity_score,
            user.captchas_solved,
            user.last_captcha_solved,   # client_req_rate_per_min, avg_h_score
            # server_req_rate_per_min,
            server_total_users
        ]

        # 2. Finalize the experience from step t-1
        if user.client_id in pending_experiences:
            prev_s, prev_a, prev_r, prev_done = pending_experiences[user.client_id]
            s_prime = s_t  # The current state is the "next_state" for the previous action

            # Store the *completed* transition from t-1
            # offline_rl_agent.remember(prev_s, prev_a, prev_r, s_prime, prev_done, user.is_bot)
            episode_reward += prev_r

        # 3. Check if user's session ended *naturally* (ran out of data)
        if user.done:
            continue  # User is done, no new action to take

        # 4. User is still active, take a new action (a_t)
        # a_t = offline_rl_agent.select_action(s_t)
        
        # a_t = 10 if humanity_score > 0.5 else 0   
        a_t = int(humanity_score * 10)

        # 5. Calculate reward (r_t) and if the action *caused* the session to end (done_t)
        r_t, done_t = calculate_reward(user, a_t)

        # print(f"{'Bottt' if user.is_bot else 'Human'} -> action: {a_t}, reward {r_t}, done: {done_t}, score: {humanity_score}")

        # 6. Store this new experience
        if done_t:
            # This is a terminal state (e.g., bot was killed).
            # We have the full experience now. Store it immediately.
            s_prime = s_t  # The 'next_state' is arbitrary, as 'done=True' nullifies it.
            # offline_rl_agent.remember(s_t, a_t, r_t, s_prime, True, user.is_bot)
            episode_reward += r_t
            
            # if user.is_bot:
            #     bot_count -= 1
            
        else:
            # This is a non-terminal state.
            # Store it as pending, waiting for s' from the next step.
            new_pending_experiences[user.client_id] = (s_t, a_t, r_t, done_t)
            user.last_captcha_solved = a_t
            next_active_users.append(user)  # User continues

    if not next_active_users:
        print(f"Final remaining humans: {sum(1 for u in active_users if not u.is_bot)}")
        print(f"Final remaining bots: {sum(1 for u in active_users if u.is_bot)}")

    # --- End of Step ---
    active_users = next_active_users
    pending_experiences = new_pending_experiences

    if not active_users:
        print(f"All users finished.")
        
print(f"Net reward: {episode_reward}")
print(f"Normalized reward: {episode_reward / (TARGET_BOT_COUNT + TARGET_HUMAN_COUNT):0.2f}")
print(f"Confusion Matrix: {conf}")


plt.figure(figsize=(12, 6))

plt.plot(timestep_counts, human_counts,
         label="Humans",
         linestyle="-",
         linewidth=2)

plt.plot(timestep_counts, bot_counts,
         label="Bots",
         linestyle="--",
         linewidth=2)

plt.xlabel("Timestep")
plt.ylabel("Number of Users")
plt.title("Human vs Bot Population Over Time")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# --- Starting Offline Training Simulator ---
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.
# Creating population: 85 humans, 1000 bots
# Final remaining humans: 56
# Final remaining bots: 163
# All users finished.
# Net reward: -301096.0
# Normalized reward: -277.51
# Confusion Matrix: {'human': {'predicted': {'human': 754, 'bot': 147}}, 'bot': {'predicted': {'human': 1339, 'bot': 1793}}}

# %%
import json 

with open("eval_dqn_ablation.json", "r") as f:
    dct = json.load(f)

dct.keys()
# Out:
# dict_keys(['0', '20', '100', '200', '500', '1000'])

# %%
metrics = dct["0"].keys()
metrics
# human_counts = dct["0"]["human_counts"]
# bot_counts = dct["0"]["bot_counts"]
# Out:
# dict_keys(['session_rew', 'h_session_rew', 'b_session_rew', 'step_rew', 'h_step_rew', 'b_step_rew', 'rem_h', 'rem_b'])

# %%
import numpy as np

for key in dct.keys():
    for metric in metrics:
        arr = dct[key][metric]
        np_arr = np.array(arr)
        # print(np_arr)
        print(key, metric)
        print(np_arr.mean(), np_arr.std())
# Out:
# 0 session_rew
# 173.218 11.083055354910037
# 0 h_session_rew
# 173.218 11.083055354910037
# 0 b_session_rew
# 0.0 0.0
# 0 step_rew
# 14.74574983225327 0.8228450253924429
# 0 h_step_rew
# 14.74574983225327 0.8228450253924429
# 0 b_step_rew
# 0.0 0.0
# 0 rem_h
# 95.5 1.91049731745428
# 0 rem_b
# 0.0 0.0
# 20 session_rew
# -78.07708333333332 48.64390553817554
# 20 h_session_rew
# 180.89000000000001 11.186886966444243
# 20 b_session_rew
# -1372.9125 290.5688711927862
# 20 step_rew
# -6.854378475828111 4.171971262555331
# 20 h_step_rew
# 15.370148358017246 0.8548855743320709
# 20 b_step_rew
# -158.33015749999566 6.656761009401573
# 20 rem_h
# 96.0 1.7320508075688772
# 20 rem_b
# 13.7 2.6095976701399777
# 100 session_rew
# -573.40775 62.09243062211769
# 100 h_session_rew
# 186.11700000000002 7.926714388698513
# 100 b_session_rew
# -1333.1125000000002 120.52961422924244
# 100 step_rew
# -56.14249293052019 4.332019844995522
# 100 h_step_rew
# 15.686603231250478 0.605274043808606
# ...

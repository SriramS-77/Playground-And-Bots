# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# IEEE STYLE SETTINGS
# -----------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 8,
    "axes.labelsize": 8,
    "axes.titlesize": 9,
    "legend.fontsize": 7,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "figure.dpi": 300
})

# -----------------------------
# DATA (across simulations)
# -----------------------------
models = ["LinUCB", "Thompson Sampling", "DQN",
          "DQN w/o H-Score", "Single Threshold", "Multi Threshold"]

DI = np.array([
    [96,100,89,98,51,69],
    [82,95,74,33,53,60],
    [29,87,63,25,41,54],
    [17,15.5,71.5,38,45.5,49.5],
    [18.2,21.8,72.2,28.6,42.2,52.2],
    [20.1,36.9,72.8,29.9,42.2,48]
])

BOS = np.array([
    [0.96,1,0.89,0.98,0.51,0.69],
    [0.9082,0.9744,0.8644,0.5158,0.7203,0.7719],
    [0.5008,0.9328,0.8142,0.4346,0.6394,0.7617],
    [0.3183,0.3562,0.8549,0.5843,0.6739,0.7445],
    [0.3323,0.4313,0.8534,0.4664,0.6542,0.7524],
    [0.3594,0.5744,0.8490,0.5011,0.6597,0.7291]
])

SPF1 = np.array([
    [0.9796,1,0.9418,0.9899,0.6755,0.8166],
    [0.9255,0.9950,0.9495,0.9289,0.7296,0.7831],
    [0.4892,0.9378,0.8103,0.7212,0.6242,0.75],
    [0.3089,0.3259,0.81,0.6154,0.6310,0.6635],
    [0.3101,0.3522,0.7536,0.3596,0.5231,0.5506],
    [0.3121,0.4505,0.7614,0.2240,0.4160,0.3881]
])

SIF1 = np.array([
    [0.9796,1,0.9418,0.9899,0.6755,0.8166],
    [0.9063,0.9756,0.8785,0.7452,0.7117,0.7647],
    [0.4892,0.9378,0.8103,0.7212,0.6242,0.75],
    [0.3140,0.3424,0.8504,0.7559,0.6604,0.7349],
    [0.3284,0.4173,0.8487,0.7330,0.6383,0.7399],
    [0.3551,0.5651,0.8465,0.7325,0.6428,0.7143]
])

datasets = [DI, BOS, SPF1, SIF1]
titles = ["DI", "BOS", "SP-F1", "SI-F1"]

# -----------------------------
# PLOTTING
# -----------------------------
fig, axes = plt.subplots(2, 2, figsize=(7.2, 4.8))
axes = axes.flatten()

bar_width = 0.6
x = np.arange(len(models))

for ax, data, title in zip(axes, datasets, titles):

    means = np.mean(data, axis=0)
    stds = np.std(data, axis=0)

    bars = ax.bar(
        x, means, bar_width,
        yerr=stds,
        capsize=3,
        edgecolor='black',
        linewidth=0.6,
        color='white'
    )

    # Mean marker overlay (IEEE clean style)
    ax.scatter(x, means, marker='D', color='black', s=20, zorder=3)

    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(models, rotation=45, ha='right')
    ax.grid(True, axis='y', linestyle='--', linewidth=0.5)
    ax.set_axisbelow(True)

plt.tight_layout()
plt.savefig("ieee_barplots.pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# IEEE STYLE SETTINGS
# -----------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 8,
    "axes.labelsize": 8,
    "axes.titlesize": 9,
    "legend.fontsize": 6,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "figure.dpi": 300
})

models = ["LinUCB", "TS", "DQN",
          "DQN w/o H", "Single Th.", "Multi Th."]

sim_labels = ["0", "20", "100", "200", "500", "1000"]

# -----------------------------
# DATA
# -----------------------------
DI = np.array([
    [96,100,89,98,51,69],
    [82,95,74,33,53,60],
    [29,87,63,25,41,54],
    [17,15.5,71.5,38,45.5,49.5],
    [18.2,21.8,72.2,28.6,42.2,52.2],
    [20.1,36.9,72.8,29.9,42.2,48]
])

BOS = np.array([
    [0.96,1,0.89,0.98,0.51,0.69],
    [0.9082,0.9744,0.8644,0.5158,0.7203,0.7719],
    [0.5008,0.9328,0.8142,0.4346,0.6394,0.7617],
    [0.3183,0.3562,0.8549,0.5843,0.6739,0.7445],
    [0.3323,0.4313,0.8534,0.4664,0.6542,0.7524],
    [0.3594,0.5744,0.8490,0.5011,0.6597,0.7291]
])

SPF1 = np.array([
    [0.9796,1,0.9418,0.9899,0.6755,0.8166],
    [0.9255,0.9950,0.9495,0.9289,0.7296,0.7831],
    [0.4892,0.9378,0.8103,0.7212,0.6242,0.75],
    [0.3089,0.3259,0.81,0.6154,0.6310,0.6635],
    [0.3101,0.3522,0.7536,0.3596,0.5231,0.5506],
    [0.3121,0.4505,0.7614,0.2240,0.4160,0.3881]
])

SIF1 = np.array([
    [0.9796,1,0.9418,0.9899,0.6755,0.8166],
    [0.9063,0.9756,0.8785,0.7452,0.7117,0.7647],
    [0.4892,0.9378,0.8103,0.7212,0.6242,0.75],
    [0.3140,0.3424,0.8504,0.7559,0.6604,0.7349],
    [0.3284,0.4173,0.8487,0.7330,0.6383,0.7399],
    [0.3551,0.5651,0.8465,0.7325,0.6428,0.7143]
])

datasets = [DI, BOS, SPF1, SIF1]
titles = ["DI", "BOS", "SP-F1", "SI-F1"]

# -----------------------------
# PLOTTING
# -----------------------------
fig, axes = plt.subplots(2, 2, figsize=(7.2, 4.8))
axes = axes.flatten()

num_models = len(models)
num_sims = len(sim_labels)

bar_width = 0.12
x = np.arange(num_models)

# colors = ['0.2','0.35','0.5','0.65','0.8','0.9']  # grayscale for IEEE

colors = [
    '#4E79A7',  # blue
    '#59A14F',  # green
    '#F28E2B',  # orange
    '#E15759',  # red
    '#76B7B2',  # teal
    '#B07AA1'   # purple
]

colors = [
    '#4CAF50',  # 0 bots — green (safe)
    '#8BC34A',  # 20 bots — light green
    '#FFC107',  # 100 bots — yellow
    '#FF9800',  # 200 bots — orange
    '#F44336',  # 500 bots — red
    '#B71C1C'   # 1000 bots — dark red (danger)
]



for ax, data, title in zip(axes, datasets, titles):

    for i in range(num_sims):
        ax.bar(
            x + (i - num_sims/2) * bar_width + bar_width/2,
            data[i],
            width=bar_width,
            color=colors[i],
            edgecolor='black',
            linewidth=0.3,
            label=sim_labels[i] if title == "DI" else ""
        )

    # Mean and std across simulations
    means = np.mean(data, axis=0)
    stds = np.std(data, axis=0)

    for j in range(num_models):
        center = x[j]

        # translucent std band
        ax.fill_between(
            [center - bar_width*3, center + bar_width*3],
            means[j] - stds[j],
            means[j] + stds[j],
            color='black',
            alpha=0.18,
            zorder=1
        )

        # mean line
        ax.hlines(
            means[j],
            center - bar_width*3,
            center + bar_width*3,
            colors='black',
            linewidth=0.8,
            linestyles='--'
        )

    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(models, rotation=45, ha='right')
    ax.grid(True, axis='y', linestyle='--', linewidth=0.4)
    ax.set_axisbelow(True)

# axes[0].legend(title="Sim", ncol=3, frameon=False)

handles, labels = axes[0].get_legend_handles_labels()

fig.legend(
    handles, labels,
    title="Sim",
    loc="upper right",
    bbox_to_anchor=(0.98, 0.98),
    frameon=False,
    ncol=1
)
plt.tight_layout(rect=[0, 0, 0.9, 1])

# plt.tight_layout()
plt.savefig("ieee_grouped_with_mean_std.pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# IEEE STYLE SETTINGS
# -----------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 8,
    "axes.labelsize": 8,
    "axes.titlesize": 9,
    "legend.fontsize": 6,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "figure.dpi": 300
})

models = ["DQN", "DQN w/o H", "Single Th.", "Multi Th."]

sim_labels = ["0", "20", "100", "200", "500", "1000"]

# -----------------------------
# DATA
# -----------------------------
DI = np.array([
    [89,98,51,69],
    [74,33,53,60],
    [63,25,41,54],
    [71.5,38,45.5,49.5],
    [72.2,28.6,42.2,52.2],
    [72.8,29.9,42.2,48]
])

BOS = np.array([
    [0.89,0.98,0.51,0.69],
    [0.8644,0.5158,0.7203,0.7719],
    [0.8142,0.4346,0.6394,0.7617],
    [0.8549,0.5843,0.6739,0.7445],
    [0.8534,0.4664,0.6542,0.7524],
    [0.8490,0.5011,0.6597,0.7291]
])

SPF1 = np.array([
    [0.9418,0.9899,0.6755,0.8166],
    [0.9495,0.9289,0.7296,0.7831],
    [0.8103,0.7212,0.6242,0.75],
    [0.81,0.6154,0.6310,0.6635],
    [0.7536,0.3596,0.5231,0.5506],
    [0.7614,0.2240,0.4160,0.3881]
])

SIF1 = np.array([
    [0.9418,0.9899,0.6755,0.8166],
    [0.8785,0.7452,0.7117,0.7647],
    [0.8103,0.7212,0.6242,0.75],
    [0.8504,0.7559,0.6604,0.7349],
    [0.8487,0.7330,0.6383,0.7399],
    [0.8465,0.7325,0.6428,0.7143]
])

datasets = [DI, BOS, SPF1, SIF1]
titles = ["DI", "BOS", "SP-F1", "SI-F1"]

# -----------------------------
# PLOTTING
# -----------------------------
fig, axes = plt.subplots(2, 2, figsize=(7.2, 4.8))
axes = axes.flatten()

num_models = len(models)
num_sims = len(sim_labels)

bar_width = 0.12
x = np.arange(num_models)

colors = [
    '#4CAF50',  # 0 bots — green (safe)
    '#8BC34A',  # 20 bots — light green
    '#FFC107',  # 100 bots — yellow
    '#FF9800',  # 200 bots — orange
    '#F44336',  # 500 bots — red
    '#B71C1C'   # 1000 bots — dark red (danger)
]



for ax, data, title in zip(axes, datasets, titles):

    for i in range(num_sims):
        ax.bar(
            x + (i - num_sims/2) * bar_width + bar_width/2,
            data[i],
            width=bar_width,
            color=colors[i],
            edgecolor='black',
            linewidth=0.3,
            label=sim_labels[i] if title == "DI" else ""
        )

    # Mean and std across simulations
    means = np.mean(data, axis=0)
    stds = np.std(data, axis=0)

    for j in range(num_models):
        center = x[j]

        # translucent std band
        ax.fill_between(
            [center - bar_width*3, center + bar_width*3],
            means[j] - stds[j],
            means[j] + stds[j],
            color='black',
            alpha=0.18,
            zorder=1
        )

        # mean line
        ax.hlines(
            means[j],
            center - bar_width*3,
            center + bar_width*3,
            colors='black',
            linewidth=0.8,
            linestyles='--'
        )

    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(models, rotation=45, ha='right')
    ax.grid(True, axis='y', linestyle='--', linewidth=0.4)
    ax.set_axisbelow(True)

# axes[0].legend(title="Sim", ncol=3, frameon=False)

handles, labels = axes[0].get_legend_handles_labels()

fig.legend(
    handles, labels,
    title="Bot Volume",
    loc="upper right",
    bbox_to_anchor=(0.98, 0.98),
    frameon=False,
    ncol=1
)
plt.tight_layout(rect=[0, 0, 0.88, 1])

# plt.tight_layout()
# plt.savefig("ieee_grouped_with_mean_std.pdf", bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# IEEE STYLE SETTINGS
# -----------------------------
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 8,
    "axes.labelsize": 8,
    "axes.titlesize": 9,
    "legend.fontsize": 6,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
    "figure.dpi": 300
})

models = ["LinUCB", "TS", "DQN"]

sim_labels = ["0", "20", "100", "200", "500", "1000"]

# -----------------------------
# DATA
# -----------------------------
DI = np.array([
    [96,100,89],
    [82,95,74],
    [29,87,63],
    [17,15.5,71.5],
    [18.2,21.8,72.2],
    [20.1,36.9,72.8]
])

BOS = np.array([
    [0.96,1,0.89,],
    [0.9082,0.9744,0.8644,],
    [0.5008,0.9328,0.8142,],
    [0.3183,0.3562,0.8549,],
    [0.3323,0.4313,0.8534,],
    [0.3594,0.5744,0.8490,]
])

SPF1 = np.array([
    [0.9796,1,0.9418,],
    [0.9255,0.9950,0.9495,],
    [0.4892,0.9378,0.8103,],
    [0.3089,0.3259,0.81,],
    [0.3101,0.3522,0.7536,],
    [0.3121,0.4505,0.7614,]
])

SIF1 = np.array([
    [0.9796,1,0.9418,],
    [0.9063,0.9756,0.8785,],
    [0.4892,0.9378,0.8103,],
    [0.3140,0.3424,0.8504,],
    [0.3284,0.4173,0.8487,],
    [0.3551,0.5651,0.8465,]
])

datasets = [DI, BOS, SPF1, SIF1]
titles = ["DI", "BOS", "SP-F1", "SI-F1"]

# -----------------------------
# PLOTTING
# -----------------------------
fig, axes = plt.subplots(2, 2, figsize=(7.2, 4.8))
axes = axes.flatten()

num_models = len(models)
num_sims = len(sim_labels)

bar_width = 0.12
x = np.arange(num_models)

# colors = ['0.2','0.35','0.5','0.65','0.8','0.9']  # grayscale for IEEE

colors = [
    '#4E79A7',  # blue
    '#59A14F',  # green
    '#F28E2B',  # orange
    '#E15759',  # red
    '#76B7B2',  # teal
    '#B07AA1'   # purple
]

colors = [
    '#4CAF50',  # 0 bots — green (safe)
    '#8BC34A',  # 20 bots — light green
    '#FFC107',  # 100 bots — yellow
    '#FF9800',  # 200 bots — orange
    '#F44336',  # 500 bots — red
    '#B71C1C'   # 1000 bots — dark red (danger)
]



for ax, data, title in zip(axes, datasets, titles):

    for i in range(num_sims):
        ax.bar(
            x + (i - num_sims/2) * bar_width + bar_width/2,
            data[i],
            width=bar_width,
            color=colors[i],
            edgecolor='black',
            linewidth=0.3,
            label=sim_labels[i] if title == "DI" else ""
        )

    # Mean and std across simulations
    means = np.mean(data, axis=0)
    stds = np.std(data, axis=0)

    for j in range(num_models):
        center = x[j]

        # translucent std band
        ax.fill_between(
            [center - bar_width*3, center + bar_width*3],
            means[j] - stds[j],
            means[j] + stds[j],
            color='black',
            alpha=0.18,
            zorder=1
        )

        # mean line
        ax.hlines(
            means[j],
            center - bar_width*3,
            center + bar_width*3,
            colors='black',
            linewidth=0.8,
            linestyles='--'
        )

    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(models, rotation=45, ha='right')
    ax.grid(True, axis='y', linestyle='--', linewidth=0.4)
    ax.set_axisbelow(True)

# axes[0].legend(title="Sim", ncol=3, frameon=False)

handles, labels = axes[0].get_legend_handles_labels()

fig.legend(
    handles, labels,
    title="Sim",
    loc="upper right",
    bbox_to_anchor=(0.98, 0.98),
    frameon=False,
    ncol=1
)
plt.tight_layout(rect=[0, 0, 0.9, 1])

# plt.tight_layout()
# plt.savefig("ieee_grouped_with_mean_std.pdf", bbox_inches='tight')
plt.show()

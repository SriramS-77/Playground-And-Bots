# %% [markdown]
# # Benchmark for LinUCB

# %%
import json
import os
import random
from copy import deepcopy
from scoring_service.HumanityScorer import scorer

# Import the new offline agent
from rl_service_offline import offline_rl_agent

# --- Configuration ---
DATA_DIR = "data"
# MODEL_SAVE_PATH = "models/offline_rl_model.pth"

# Simulation Hyperparameters
TARGET_HUMAN_COUNT = int(random.random() * 20) + 80   # Between 80-100  # Number of "real" human users to simulate
TARGET_BOT_COUNT = random.choice([0, 20, 50, 100, 200, 1000])  # Number of bot users to simulate (for DoS)
SIMULATION_STEP_SECONDS = 10  # How often the RL agent is called (matches frontend)
SESSION_CHUNK_SIZE = int(SIMULATION_STEP_SECONDS * 1000)  # In milliseconds

HUMAN_COMFORT_FACTOR = 3

conf = {
    "human": {"predicted": {"human": 0, "bot": 0}},
    "bot": {"predicted": {"human": 0, "bot": 0}}
}
# Out:
# Offline RL Agent using device: cpu

# %%
def update_human_bot_population(human_count=None, bot_count=None):
    global TARGET_HUMAN_COUNT, TARGET_BOT_COUNT, conf
    TARGET_HUMAN_COUNT = random.randint(80, 100) if human_count is None else human_count
    TARGET_BOT_COUNT = random.choice([0, 20, 50, 100, 200, 1000]) if bot_count is None else bot_count
    
    # Reset Confusion Matrix for the new episode
    for key in ["human", "bot"]:
        for pred in ["human", "bot"]:
            conf[key]["predicted"][pred] = 0

def get_humanity_score(mouse_movement):
    if not mouse_movement:
        return None
    formatted_movements = [[m['x'], m['y']] for m in mouse_movement]
    try:
        # Assuming scorer is the LSTM model
        prediction = scorer.predict(formatted_movements)
        return float(prediction)
    except Exception as e:
        return 0.5
    

def load_session_data(data_dir):
    """Loads all human and bot raw data files."""
    human_sessions = []
    bot_sessions = []
    print(f"Loading raw session data from {data_dir}...")
    for filename in os.listdir(data_dir):
        if not filename.endswith('.json'): continue
        filepath = os.path.join(data_dir, filename)
        try:
            with open(filepath, 'r') as f:
                data = json.load(f)
            if filename.startswith('human'):
                human_sessions.append(data)
            elif filename.startswith('bot'):
                bot_sessions.append(data)
        except Exception as e:
            print(f"Warning: Could not load or parse {filename}. Error: {e}")

    print(f"Loaded {len(human_sessions)} human sessions and {len(bot_sessions)} bot sessions.")
    if not human_sessions or not bot_sessions:
        print("Error: Not enough data to run simulation. Please run bot simulator and browse site.")
        exit()
    return human_sessions, bot_sessions


def perturb_mouse_data(movements):
    """Creates a 'new' user by slightly altering existing mouse data."""
    if not movements: return []
    # Add small random noise to each coordinate
    noise_x = random.randint(-5//5, 5//5)
    noise_y = random.randint(-5//5, 5//5)
    return [{**m, 'x': m['x'] + noise_x, 'y': m['y'] + noise_y, 'timestamp': m['timestamp']} for m in movements]


def get_session_chunks(session_data, chunk_size_ms, target_chunks_size=12):
    """Splits a full session's mouse data into 10-second (step) chunks."""
    start_time = session_data['timestamps']['start']
    movements = session_data.get('mouse_movements', [])
    if not movements: return [[]]  # Return one empty chunk

    chunks = []
    current_chunk = []
    chunk_end_time = start_time + chunk_size_ms

    for move in movements:
        if move['timestamp'] <= chunk_end_time:
            current_chunk.append(move)
        else:
            chunks.append(current_chunk)
            if len(chunks) == target_chunks_size:
                return chunks
            # Handle multiple empty steps
            while move['timestamp'] > chunk_end_time + chunk_size_ms:
                chunks.append([])
                if len(chunks) == target_chunks_size:
                    return chunks
                chunk_end_time += chunk_size_ms

            current_chunk = [move]
            chunk_end_time += chunk_size_ms

    chunks.append(current_chunk)  # Add the last chunk
    if len(chunks) < target_chunks_size:
        chunks = chunks + get_session_chunks(session_data, chunk_size_ms, target_chunks_size=target_chunks_size - len(chunks))
    return chunks

class SimulatedUser:
    """Represents a single concurrent user (bot or human) in the simulation."""

    def __init__(self, base_session_data, is_bot):
        self.is_bot = is_bot
        self.client_id = f"{'bot' if is_bot else 'human'}_{random.randint(10000, 99999)}"
        self.captchas_solved = 0
        self.last_captcha_solved = -1
        self.done = False  # Is this user's session over?
        self.last_humanity_score = None
        self.average_humanity_score = 0.5
        self.n_humanity_score = 0

        # *** NEW: Assign a "strength" to each bot ***
        # This is the max threat level (0-9) the bot can "beat"
        # A threat level of 10 will *always* kill the bot.
        if self.is_bot:
            self.bot_strength = random.randint(0, 9)
        else:
            self.bot_strength = None  # Humans don't have a strength

        # Perturb and chunk the data to create a new, unique session
        perturbed_movements = perturb_mouse_data(base_session_data.get('mouse_movements', []))
        perturbed_session = {**base_session_data, 'mouse_movements': perturbed_movements}
        self.session_chunks = get_session_chunks(perturbed_session, SESSION_CHUNK_SIZE)
        self.current_chunk_index = 0

    def get_step_data(self):
        """Gets the mouse data for the current 10-second step."""
        if self.done or self.current_chunk_index >= len(self.session_chunks):
            self.done = True
            return None  # This user has finished their session

        chunk = self.session_chunks[self.current_chunk_index]
        self.current_chunk_index += 1
        return chunk
    
    def update_stats(self, h_score):
        if h_score is not None:
            self.last_humanity_score = h_score
            self.average_humanity_score = (self.average_humanity_score * self.n_humanity_score + h_score) / (self.n_humanity_score + 1)
            self.n_humanity_score += 1


    def reset_session(self):
        """Called when a bot is 'killed'."""
        self.captchas_solved = 0
        self.done = True

# %%
import math

def calculate_reward(user, threat_level):
    """
    Refined reward function for balancing Security vs. UX.
    Weights are normalized so that one 'Happy Human' is roughly 
    equivalent to one 'Caught Bot'.
    """
    reward = 0
    done = False
    
    # Constants for tuning
    MAX_REWARD = 50.0        # Baseline for a 'Perfect' action
    LEAKAGE_PENALTY = -150.0 # Bot got through (Critical Failure)
    FRICTION_BASE = 2.0      # Sensitivity to human annoyance
    
    if user.is_bot:
        if threat_level > user.bot_strength:
            # Bot CAUGHT
            # We want the lowest threat level that still beats the bot.
            # Overkill penalty: (threat_level - strength) 
            overkill = (threat_level - user.bot_strength)
            reward = MAX_REWARD - (overkill * 2.0) 
            done = True
            user.reset_session()
        else:
            # Bot LEAKED
            # Penalty scales with how much the bot 'outsmarted' the system
            gap = user.bot_strength - threat_level
            reward = LEAKAGE_PENALTY - (gap * 5.0)
            user.captchas_solved += 1
            
    else:
        # HUMAN logic
        if threat_level == 0:
            # Perfect score for zero friction
            reward = MAX_REWARD
        else:
            # Non-linear frustration: Level 1 is okay, Level 10 is infuriating.
            # Using an exponential penalty for human annoyance.
            frustration = math.pow(FRICTION_BASE, threat_level)
            reward = (MAX_REWARD / 2.0) - frustration
            
        user.captchas_solved += 1

    # Check if human gave up (Simulated patience)
    if threat_level == 10 or random.random() * (threat_level - 6) > 0.5:
        done = True # Human abandoned site due to high friction

    return reward, done

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class FeatureNN(nn.Module):
    def __init__(self, input_dim=5, embed_dim=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, embed_dim)
        )

    def forward(self, x):
        return self.net(x)

class DeepContextualBandit:
    def __init__(self, num_arms=11, context_dim=5, embed_dim=64, alpha=1.0, lr=1e-3):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.num_arms = num_arms
        self.alpha = alpha

        # neural network embedding
        self.feature_nn = FeatureNN(context_dim, embed_dim).to(self.device)
        self.optimizer = optim.Adam(self.feature_nn.parameters(), lr=lr)

        # UCB "linear head" parameters
        self.embed_dim = embed_dim
        self.As = [torch.eye(embed_dim).to(self.device) for _ in range(num_arms)]
        self.bs = [torch.zeros(embed_dim).to(self.device) for _ in range(num_arms)]

    def select_action(self, context):
        """
        Get UCB scores for each arm and pick best.
        context: torch.Tensor shape (context_dim,)
        """
        z = self.feature_nn(context.to(self.device))  # embed

        best_arm = None
        best_score = -float('inf')

        with torch.no_grad():
            for a in range(self.num_arms):
                A = self.As[a]
                b = self.bs[a]

                invA = torch.linalg.inv(A)
                theta_hat = invA @ b  # linear estimate

                mean = z @ theta_hat
                # UCB uncertainty
                unc = self.alpha * torch.sqrt((z @ invA) @ z)
                score = mean + unc

                if score > best_score:
                    best_score = score
                    best_arm = a

        return best_arm

    def update(self, context, action, reward):
        """
        Update linear head and train features with supervised signal.
        """
        context = context.to(self.device)
        reward = torch.tensor(reward, dtype=torch.float32, device=self.device)

        # get feature
        z = self.feature_nn(context)

        # ----------- Update linear head (NO GRAD) -----------
        with torch.no_grad():
            z_detached = z.detach()
            # update linear model for chosen arm
            A = self.As[action]
            b = self.bs[action]

            self.As[action] = A + torch.outer(z_detached, z_detached)
            self.bs[action] = b + reward * z_detached
        # # update linear model for chosen arm
        # A = self.As[action]
        # b = self.bs[action]

        # self.As[action] = A + torch.outer(z, z)
        # self.bs[action] = b + reward * z
        
        # Optional: train neural network to regress reward
        # Use current UCB arm predictor as pseudo target
        pred = (z @ torch.linalg.inv(self.As[action]) @ self.bs[action])
        loss = (pred - reward).pow(2)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def load(self, filepath):
        checkpoint = torch.load(filepath)
        self.feature_nn.load_state_dict(checkpoint["feature_nn"])
        self.optimizer.load_state_dict(checkpoint["optimizer"])
        self.As = checkpoint["As"]
        self.bs = checkpoint["bs"]
        self.num_arms = checkpoint["num_arms"]
        self.embed_dim = checkpoint["embed_dim"]
        self.alpha = checkpoint["alpha"]
        print(f"Model loaded successfully from {filepath}.")

    def save(self, filepath="linucb_model_0.pt"):
        checkpoint = {
            'feature_nn': self.feature_nn.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            "As": [A.cpu() for A in self.As],
            "bs": [b.cpu() for b in self.bs],
            "num_arms": self.num_arms,
            "embed_dim": self.embed_dim,
            "alpha": self.alpha
        }

        torch.save(checkpoint, filepath)
        print("Offline model saved.")

# %%
import torch
import random
import numpy as np
from copy import deepcopy

# Configuration Constants
HUMAN_BUFFER = []
BOT_BUFFER = []
BUFFER_SIZE = 2000
BATCH_SIZE = 64
TRAIN_FREQUENCY = 30  # Train every 10 global steps

REWARDS_LOG = []
BOT_REWARD = []
HUMAN_REWARD = []


def normalize_context(context_list):
    """Ensures all context features are in a similar 0-1 range for NN stability."""
    # Context indices: 0: score, 1: avg_score, 2: solved, 3: last_solved, 4: server_total
    # Solved counts can be high, so we squash them with tanh or log
    ctx = np.array(context_list, dtype=np.float32)
    ctx[2] = np.tanh(ctx[2] / 10.0)  # Solved count normalization
    ctx[3] = np.tanh(ctx[3] / 10.0)  # Last solved normalization
    ctx[4] = np.tanh(ctx[4] / 200.0) # Server load normalization
    return torch.Tensor(ctx)

def train_balanced_step(bandit):
    """Samples 50% humans and 50% bots to prevent mode collapse."""
    if len(HUMAN_BUFFER) < BATCH_SIZE // 2 or len(BOT_BUFFER) < BATCH_SIZE // 2:
        return # Not enough data yet

    # Sample equal amounts
    h_batch = random.sample(HUMAN_BUFFER, BATCH_SIZE // 2)
    b_batch = random.sample(BOT_BUFFER, BATCH_SIZE // 2)
    
    combined_batch = h_batch + b_batch
    random.shuffle(combined_batch)
    
    # Perform update using the bandit's internal training method
    # Note: You might need to adapt this based on your bandit's specific API
    for ctx, act, rew in combined_batch:
        bandit.update(ctx, act, rew)
        

bandit = DeepContextualBandit(num_arms=11, context_dim=5)

base_human_sessions, base_bot_sessions = load_session_data(DATA_DIR)
# Out:
# Loading raw session data from data...
# Loaded 32 human sessions and 41 bot sessions.

# %%
# bandit.load("./other_models/linucb/models/model_3.pt")
# bandit.load("./other_models/linucb/models/best_model.pt")
bandit.load("./other_models/linucb/models/4/best_model_0.pt")

update_human_bot_population(human_count=100, bot_count=100)
# Out:
# Model loaded successfully from ./other_models/linucb/models/4/best_model_0.pt.

# %%
# Track population over time
human_counts = []
bot_counts = []
timestep_counts = []
current_timestep = 0

# This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
pending_experiences = {}
episode_reward = 0

print(f"Population ::: Human: {TARGET_HUMAN_COUNT} | Bot: {TARGET_BOT_COUNT}")
global_step_counter = 0
episode_reward = 0
episode_h_step_counter = 0
episode_b_step_counter = 0
episode_human_reward = 0
episode_bot_reward = 0
    
# Initialize session population
active_users = []
# Load and wrap your human/bot sessions
for _ in range(TARGET_HUMAN_COUNT):
    active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
for _ in range(TARGET_BOT_COUNT):
    active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))

random.shuffle(active_users)

while active_users:
    human_count = sum(1 for u in active_users if not u.is_bot)
    bot_count = sum(1 for u in active_users if u.is_bot)
    
    human_counts.append(human_count)
    bot_counts.append(bot_count)
    timestep_counts.append(current_timestep)
    current_timestep += 1
    
    server_total_users = len(active_users)
    next_active_users = []

    for user in active_users:
        global_step_counter += 1
            
        # 1. Perception: Get humanity score
        mouse_data = user.get_step_data()
        h_score = get_humanity_score(mouse_data)
            
        # Update user's internal tracking
        user.update_stats(h_score) # Logic moved to a helper for cleanliness

        if h_score is None:
            h_score = user.average_humanity_score

        conf["bot" if user.is_bot else "human"]["predicted"]["bot" if h_score >= .5 else "human"] += 1

        # 2. Context Building
        raw_context = [
            h_score,
            user.average_humanity_score,
            user.captchas_solved,
            user.last_captcha_solved,
            server_total_users
        ]
        context = normalize_context(raw_context)

        # 3. Action Selection
        # Exploration logic (epsilon-greedy) is usually inside select_action
        action = bandit.select_action(context)

        # 4. Environment Feedback
        reward, done = calculate_reward(user, action) 
        episode_reward += reward

        if user.is_bot:
            BOT_REWARD.append(reward)
            episode_bot_reward += reward
            episode_b_step_counter += 1
        else:
            HUMAN_REWARD.append(reward)
            episode_human_reward += reward
            episode_h_step_counter += 1
        # REWARDS_LOG.append(reward)

        # # 5. Balanced Memory Storage
        # target_buffer = BOT_BUFFER if user.is_bot else HUMAN_BUFFER
        # target_buffer.append((context, action, reward))
            
        # # Keep buffer size manageable
        # if len(target_buffer) > BUFFER_SIZE:
        #     target_buffer.pop(0)

        # # 6. Balanced Training Trigger
        # if global_step_counter % TRAIN_FREQUENCY == 0:
        #     train_balanced_step(bandit)

        if not (user.done or done):
            next_active_users.append(user)
        
    active_users = next_active_users

# Metrics logging...
avg_rew = episode_reward / (episode_h_step_counter + episode_b_step_counter)   # (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
avg_human_rew = episode_human_reward / episode_h_step_counter
avg_bot_rew = episode_bot_reward / episode_b_step_counter if episode_b_step_counter else 0
print(f"Total Reward: {episode_reward:.2f} | Avg: {avg_rew:.2f} | Avg Human: {avg_human_rew:.2f} | Avg Bot: {avg_bot_rew:.2f}")
    
avg_session_rew = episode_reward / (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
avg_h_session_rew = episode_human_reward / (TARGET_HUMAN_COUNT)
avg_b_session_rew = episode_bot_reward / TARGET_BOT_COUNT if TARGET_BOT_COUNT else 0
print(f"Average Session Rewards::: Mean: {avg_session_rew:.2f} | Human: {avg_h_session_rew:.2f} | Bot: {avg_b_session_rew:.2f}")

print("Confusion Matrix:\n", conf)

import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))

plt.plot(timestep_counts, human_counts,
         label="Humans",
         linestyle="-",
         linewidth=2)

plt.plot(timestep_counts, bot_counts,
         label="Bots",
         linestyle="--",
         linewidth=2)

plt.xlabel("Timestep")
plt.ylabel("Number of Users")
plt.title("Human vs Bot Population Over Time")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Population ::: Human: 100 | Bot: 100
# Total Reward: -22735.00 | Avg: -33.24 | Avg Human: -32.74 | Avg Bot: -35.19
# Average Session Rewards::: Mean: -113.67 | Human: -178.09 | Bot: -49.26
# Confusion Matrix:
#  {'human': {'predicted': {'human': 449, 'bot': 95}}, 'bot': {'predicted': {'human': 51, 'bot': 89}}}

# %%
bandit.load("./other_models/linucb/models/4/best_model_1.pt")

update_human_bot_population(human_count=100, bot_count=100)
# Out:
# Model loaded successfully from ./other_models/linucb/models/4/best_model_1.pt.

# %%
import json

bot_counts_lst = [0, 20, 100, 200, 500, 1000]
h_count = 100

dct = dict()

for b_count in bot_counts_lst:
    update_human_bot_population(human_count=h_count, bot_count=b_count)

    # Track population over time
    human_counts = []
    bot_counts = []
    timestep_counts = []
    current_timestep = 0

    # This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
    pending_experiences = {}
    episode_reward = 0

    print(f"Population ::: Human: {TARGET_HUMAN_COUNT} | Bot: {TARGET_BOT_COUNT}")
    global_step_counter = 0
    episode_reward = 0
    episode_h_step_counter = 0
    episode_b_step_counter = 0
    episode_human_reward = 0
    episode_bot_reward = 0
        
    # Initialize session population
    active_users = []
    # Load and wrap your human/bot sessions
    for _ in range(TARGET_HUMAN_COUNT):
        active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
    for _ in range(TARGET_BOT_COUNT):
        active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))

    random.shuffle(active_users)

    while active_users:
        human_count = sum(1 for u in active_users if not u.is_bot)
        bot_count = sum(1 for u in active_users if u.is_bot)
        
        human_counts.append(human_count)
        bot_counts.append(bot_count)
        timestep_counts.append(current_timestep)
        current_timestep += 1
        
        server_total_users = len(active_users)
        next_active_users = []

        for user in active_users:
            global_step_counter += 1
                
            # 1. Perception: Get humanity score
            mouse_data = user.get_step_data()
            h_score = get_humanity_score(mouse_data)
                
            # Update user's internal tracking
            user.update_stats(h_score) # Logic moved to a helper for cleanliness

            if h_score is None:
                h_score = user.average_humanity_score

            conf["bot" if user.is_bot else "human"]["predicted"]["bot" if h_score >= .5 else "human"] += 1

            # 2. Context Building
            raw_context = [
                h_score,
                user.average_humanity_score,
                user.captchas_solved,
                user.last_captcha_solved,
                server_total_users
            ]
            context = normalize_context(raw_context)

            # 3. Action Selection
            # Exploration logic (epsilon-greedy) is usually inside select_action
            action = bandit.select_action(context)

            # 4. Environment Feedback
            reward, done = calculate_reward(user, action) 
            episode_reward += reward

            if user.is_bot:
                BOT_REWARD.append(reward)
                episode_bot_reward += reward
                episode_b_step_counter += 1
            else:
                HUMAN_REWARD.append(reward)
                episode_human_reward += reward
                episode_h_step_counter += 1
            # REWARDS_LOG.append(reward)

            # # 5. Balanced Memory Storage
            # target_buffer = BOT_BUFFER if user.is_bot else HUMAN_BUFFER
            # target_buffer.append((context, action, reward))
                
            # # Keep buffer size manageable
            # if len(target_buffer) > BUFFER_SIZE:
            #     target_buffer.pop(0)

            # # 6. Balanced Training Trigger
            # if global_step_counter % TRAIN_FREQUENCY == 0:
            #     train_balanced_step(bandit)

            if not (user.done or done):
                next_active_users.append(user)

        if not next_active_users:
            print(f"Final remaining humans: {sum(1 for u in active_users if not u.is_bot)}")
            print(f"Final remaining bots: {sum(1 for u in active_users if u.is_bot)}")
            
        active_users = next_active_users

    # Metrics logging...
    avg_rew = episode_reward / (episode_h_step_counter + episode_b_step_counter)   # (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
    avg_human_rew = episode_human_reward / episode_h_step_counter
    avg_bot_rew = episode_bot_reward / episode_b_step_counter if episode_b_step_counter else 0
    print(f"Total Reward: {episode_reward:.2f} | Avg: {avg_rew:.2f} | Avg Human: {avg_human_rew:.2f} | Avg Bot: {avg_bot_rew:.2f}")
        
    avg_session_rew = episode_reward / (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
    avg_h_session_rew = episode_human_reward / (TARGET_HUMAN_COUNT)
    avg_b_session_rew = episode_bot_reward / TARGET_BOT_COUNT if TARGET_BOT_COUNT else 0
    print(f"Average Session Rewards::: Mean: {avg_session_rew:.2f} | Human: {avg_h_session_rew:.2f} | Bot: {avg_b_session_rew:.2f}")

    print("Confusion Matrix:\n", conf)
    print("\n\n")

    dct[b_count] = {
        "timesteps": timestep_counts,
        "human_counts": human_counts,
        "bot_counts": bot_counts
    }

with open("eval_linucb_new1.json", "w") as f:
    json.dump(dct, f)
# Out:
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 56876.00 | Avg: 43.75 | Avg Human: 43.75 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 568.76 | Human: 568.76 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1115, 'bot': 185}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 96
# Final remaining bots: 2
# Total Reward: 45510.00 | Avg: 35.01 | Avg Human: 40.24 | Avg Bot: -101.58
# Average Session Rewards::: Mean: 379.25 | Human: 503.86 | Bot: -243.80
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1064, 'bot': 188}}, 'bot': {'predicted': {'human': 25, 'bot': 23}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 66
# Final remaining bots: 13
# Total Reward: -1283.00 | Avg: -1.12 | Avg Human: 28.40 | Avg Bot: -103.97
# Average Session Rewards::: Mean: -6.42 | Human: 253.34 | Bot: -266.17
# Confusion Matrix:
#  {'human': {'predicted': {'human': 799, 'bot': 93}}, 'bot': {'predicted': {'human': 125, 'bot': 131}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 35
# Final remaining bots: 3
# Total Reward: -3870.00 | Avg: -5.12 | Avg Human: -1.79 | Avg Bot: -12.46
# Average Session Rewards::: Mean: -12.90 | Human: -9.30 | Bot: -14.70
# Confusion Matrix:
#  {'human': {'predicted': {'human': 428, 'bot': 92}}, 'bot': {'predicted': {'human': 60, 'bot': 176}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 29
# Final remaining bots: 7
# Total Reward: -12738.00 | Avg: -12.34 | Avg Human: -24.42 | Avg Bot: -3.08
# Average Session Rewards::: Mean: -21.23 | Human: -109.39 | Bot: -3.60
# Confusion Matrix:
#  {'human': {'predicted': {'human': 366, 'bot': 82}}, 'bot': {'predicted': {'human': 144, 'bot': 440}}}
#
#
#
# Population ::: Human: 100 | Bot: 1000
# Final remaining humans: 28
# Final remaining bots: 15
# Total Reward: -20535.00 | Avg: -12.71 | Avg Human: -33.33 | Avg Bot: -5.09
# Average Session Rewards::: Mean: -18.67 | Human: -145.31 | Bot: -6.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 354, 'bot': 82}}, 'bot': {'predicted': {'human': 301, 'bot': 879}}}

# %%
import random

bot_counts_lst = [0, 20, 100, 200, 500, 1000]
h_count = 100

SAMPLE_SIZE = 10

dct = dict()

for b_count in bot_counts_lst:
    update_human_bot_population(human_count=h_count, bot_count=b_count)

    for i in range(SAMPLE_SIZE):
        random.seed(i)

        # Track population over time
        human_counts = []
        bot_counts = []
        timestep_counts = []
        current_timestep = 0

        # This dict holds the (s, a, r, done) tuple from step t-1, waiting for s' at step t
        pending_experiences = {}
        episode_reward = 0

        print(f"Population ::: Human: {TARGET_HUMAN_COUNT} | Bot: {TARGET_BOT_COUNT}")
        global_step_counter = 0
        episode_reward = 0
        episode_h_step_counter = 0
        episode_b_step_counter = 0
        episode_human_reward = 0
        episode_bot_reward = 0
            
        # Initialize session population
        active_users = []
        # Load and wrap your human/bot sessions
        for _ in range(TARGET_HUMAN_COUNT):
            active_users.append(SimulatedUser(random.choice(base_human_sessions), is_bot=False))
        for _ in range(TARGET_BOT_COUNT):
            active_users.append(SimulatedUser(random.choice(base_bot_sessions), is_bot=True))

        random.shuffle(active_users)

        while active_users:
            human_count = sum(1 for u in active_users if not u.is_bot)
            bot_count = sum(1 for u in active_users if u.is_bot)
            
            human_counts.append(human_count)
            bot_counts.append(bot_count)
            timestep_counts.append(current_timestep)
            current_timestep += 1
            
            server_total_users = len(active_users)
            next_active_users = []

            for user in active_users:
                global_step_counter += 1
                    
                # 1. Perception: Get humanity score
                mouse_data = user.get_step_data()
                h_score = get_humanity_score(mouse_data)
                    
                # Update user's internal tracking
                user.update_stats(h_score) # Logic moved to a helper for cleanliness

                if h_score is None:
                    h_score = user.average_humanity_score

                conf["bot" if user.is_bot else "human"]["predicted"]["bot" if h_score >= .5 else "human"] += 1

                # 2. Context Building
                raw_context = [
                    h_score,
                    user.average_humanity_score,
                    user.captchas_solved,
                    user.last_captcha_solved,
                    server_total_users
                ]
                context = normalize_context(raw_context)

                # 3. Action Selection
                # Exploration logic (epsilon-greedy) is usually inside select_action
                action = bandit.select_action(context)

                # 4. Environment Feedback
                reward, done = calculate_reward(user, action) 
                episode_reward += reward

                if user.is_bot:
                    BOT_REWARD.append(reward)
                    episode_bot_reward += reward
                    episode_b_step_counter += 1
                else:
                    HUMAN_REWARD.append(reward)
                    episode_human_reward += reward
                    episode_h_step_counter += 1
                # REWARDS_LOG.append(reward)

                # # 5. Balanced Memory Storage
                # target_buffer = BOT_BUFFER if user.is_bot else HUMAN_BUFFER
                # target_buffer.append((context, action, reward))
                    
                # # Keep buffer size manageable
                # if len(target_buffer) > BUFFER_SIZE:
                #     target_buffer.pop(0)

                # # 6. Balanced Training Trigger
                # if global_step_counter % TRAIN_FREQUENCY == 0:
                #     train_balanced_step(bandit)

                if not (user.done or done):
                    next_active_users.append(user)

            if not next_active_users:
                print(f"Final remaining humans: {sum(1 for u in active_users if not u.is_bot)}")
                print(f"Final remaining bots: {sum(1 for u in active_users if u.is_bot)}")
                remaining_humans = sum(1 for u in active_users if not u.is_bot)
                remaining_bots = sum(1 for u in active_users if u.is_bot)
                
            active_users = next_active_users

        # Metrics logging...
        avg_rew = episode_reward / (episode_h_step_counter + episode_b_step_counter)   # (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_human_rew = episode_human_reward / episode_h_step_counter
        avg_bot_rew = episode_bot_reward / episode_b_step_counter if episode_b_step_counter else 0
        print(f"Total Reward: {episode_reward:.2f} | Avg: {avg_rew:.2f} | Avg Human: {avg_human_rew:.2f} | Avg Bot: {avg_bot_rew:.2f}")
            
        avg_session_rew = episode_reward / (TARGET_HUMAN_COUNT + TARGET_BOT_COUNT)
        avg_h_session_rew = episode_human_reward / (TARGET_HUMAN_COUNT)
        avg_b_session_rew = episode_bot_reward / TARGET_BOT_COUNT if TARGET_BOT_COUNT else 0
        print(f"Average Session Rewards::: Mean: {avg_session_rew:.2f} | Human: {avg_h_session_rew:.2f} | Bot: {avg_b_session_rew:.2f}")

        print("Confusion Matrix:\n", conf)
        print("\n\n")

        dct[b_count] = {
            "session_rew": dct.get(b_count, {}).get("session_rew", []) + [avg_session_rew],
            "h_session_rew": dct.get(b_count, {}).get("h_session_rew", []) + [avg_h_session_rew],
            "b_session_rew": dct.get(b_count, {}).get("b_session_rew", []) + [avg_b_session_rew],
            "step_rew": dct.get(b_count, {}).get("step_rew", []) + [avg_rew],
            "h_step_rew": dct.get(b_count, {}).get("h_step_rew", []) + [avg_human_rew],
            "b_step_rew": dct.get(b_count, {}).get("b_step_rew", []) + [avg_bot_rew],
            "rem_h": dct.get(b_count, {}).get("rem_h", []) + [remaining_humans],
            "rem_b": dct.get(b_count, {}).get("rem_b", []) + [remaining_bots],
        }

with open("36_model_agg_evals/eval_linucb.json", "w") as f:
    json.dump(dct, f)

dct
# Out:
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1147, 'bot': 153}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2274, 'bot': 326}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3349, 'bot': 551}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4516, 'bot': 684}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5627, 'bot': 873}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6773, 'bot': 1027}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7918, 'bot': 1182}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 9029, 'bot': 1371}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 10137, 'bot': 1563}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 0
# Final remaining humans: 100
# Final remaining bots: 0
# Total Reward: 65000.00 | Avg: 50.00 | Avg Human: 50.00 | Avg Bot: 0.00
# Average Session Rewards::: Mean: 650.00 | Human: 650.00 | Bot: 0.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 11253, 'bot': 1747}}, 'bot': {'predicted': {'human': 0, 'bot': 0}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 17940.00 | Avg: 11.50 | Avg Human: 50.00 | Avg Bot: -181.00
# Average Session Rewards::: Mean: 149.50 | Human: 650.00 | Bot: -2353.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1147, 'bot': 153}}, 'bot': {'predicted': {'human': 74, 'bot': 186}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 19630.00 | Avg: 12.58 | Avg Human: 50.00 | Avg Bot: -174.50
# Average Session Rewards::: Mean: 163.58 | Human: 650.00 | Bot: -2268.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2274, 'bot': 326}}, 'bot': {'predicted': {'human': 144, 'bot': 376}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 20735.00 | Avg: 13.29 | Avg Human: 50.00 | Avg Bot: -170.25
# Average Session Rewards::: Mean: 172.79 | Human: 650.00 | Bot: -2213.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3349, 'bot': 551}}, 'bot': {'predicted': {'human': 226, 'bot': 554}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 18005.00 | Avg: 11.54 | Avg Human: 50.00 | Avg Bot: -180.75
# Average Session Rewards::: Mean: 150.04 | Human: 650.00 | Bot: -2349.75
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4516, 'bot': 684}}, 'bot': {'predicted': {'human': 308, 'bot': 732}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 19565.00 | Avg: 12.54 | Avg Human: 50.00 | Avg Bot: -174.75
# Average Session Rewards::: Mean: 163.04 | Human: 650.00 | Bot: -2271.75
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5627, 'bot': 873}}, 'bot': {'predicted': {'human': 364, 'bot': 936}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 19435.00 | Avg: 12.46 | Avg Human: 50.00 | Avg Bot: -175.25
# Average Session Rewards::: Mean: 161.96 | Human: 650.00 | Bot: -2278.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6773, 'bot': 1027}}, 'bot': {'predicted': {'human': 455, 'bot': 1105}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 21580.00 | Avg: 13.83 | Avg Human: 50.00 | Avg Bot: -167.00
# Average Session Rewards::: Mean: 179.83 | Human: 650.00 | Bot: -2171.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7918, 'bot': 1182}}, 'bot': {'predicted': {'human': 510, 'bot': 1310}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 21775.00 | Avg: 13.96 | Avg Human: 50.00 | Avg Bot: -166.25
# Average Session Rewards::: Mean: 181.46 | Human: 650.00 | Bot: -2161.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 9029, 'bot': 1371}}, 'bot': {'predicted': {'human': 574, 'bot': 1506}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 20020.00 | Avg: 12.83 | Avg Human: 50.00 | Avg Bot: -173.00
# Average Session Rewards::: Mean: 166.83 | Human: 650.00 | Bot: -2249.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 10137, 'bot': 1563}}, 'bot': {'predicted': {'human': 647, 'bot': 1693}}}
#
#
#
# Population ::: Human: 100 | Bot: 20
# Final remaining humans: 100
# Final remaining bots: 20
# Total Reward: 18395.00 | Avg: 11.79 | Avg Human: 50.00 | Avg Bot: -179.25
# Average Session Rewards::: Mean: 153.29 | Human: 650.00 | Bot: -2330.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 11253, 'bot': 1747}}, 'bot': {'predicted': {'human': 740, 'bot': 1860}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -158925.00 | Avg: -61.12 | Avg Human: 50.00 | Avg Bot: -172.25
# Average Session Rewards::: Mean: -794.62 | Human: 650.00 | Bot: -2239.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1147, 'bot': 153}}, 'bot': {'predicted': {'human': 320, 'bot': 980}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -161070.00 | Avg: -61.95 | Avg Human: 50.00 | Avg Bot: -173.90
# Average Session Rewards::: Mean: -805.35 | Human: 650.00 | Bot: -2260.70
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2274, 'bot': 326}}, 'bot': {'predicted': {'human': 650, 'bot': 1950}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -159250.00 | Avg: -61.25 | Avg Human: 50.00 | Avg Bot: -172.50
# Average Session Rewards::: Mean: -796.25 | Human: 650.00 | Bot: -2242.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3349, 'bot': 551}}, 'bot': {'predicted': {'human': 987, 'bot': 2913}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -159315.00 | Avg: -61.27 | Avg Human: 50.00 | Avg Bot: -172.55
# Average Session Rewards::: Mean: -796.58 | Human: 650.00 | Bot: -2243.15
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4516, 'bot': 684}}, 'bot': {'predicted': {'human': 1371, 'bot': 3829}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -160030.00 | Avg: -61.55 | Avg Human: 50.00 | Avg Bot: -173.10
# Average Session Rewards::: Mean: -800.15 | Human: 650.00 | Bot: -2250.30
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5627, 'bot': 873}}, 'bot': {'predicted': {'human': 1701, 'bot': 4799}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -157950.00 | Avg: -60.75 | Avg Human: 50.00 | Avg Bot: -171.50
# Average Session Rewards::: Mean: -789.75 | Human: 650.00 | Bot: -2229.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6773, 'bot': 1027}}, 'bot': {'predicted': {'human': 2038, 'bot': 5762}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -153985.00 | Avg: -59.23 | Avg Human: 50.00 | Avg Bot: -168.45
# Average Session Rewards::: Mean: -769.92 | Human: 650.00 | Bot: -2189.85
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7918, 'bot': 1182}}, 'bot': {'predicted': {'human': 2404, 'bot': 6696}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -157950.00 | Avg: -60.75 | Avg Human: 50.00 | Avg Bot: -171.50
# Average Session Rewards::: Mean: -789.75 | Human: 650.00 | Bot: -2229.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 9029, 'bot': 1371}}, 'bot': {'predicted': {'human': 2723, 'bot': 7677}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -157430.00 | Avg: -60.55 | Avg Human: 50.00 | Avg Bot: -171.10
# Average Session Rewards::: Mean: -787.15 | Human: 650.00 | Bot: -2224.30
# Confusion Matrix:
#  {'human': {'predicted': {'human': 10137, 'bot': 1563}}, 'bot': {'predicted': {'human': 3088, 'bot': 8612}}}
#
#
#
# Population ::: Human: 100 | Bot: 100
# Final remaining humans: 100
# Final remaining bots: 100
# Total Reward: -161590.00 | Avg: -62.15 | Avg Human: 50.00 | Avg Bot: -174.30
# Average Session Rewards::: Mean: -807.95 | Human: 650.00 | Bot: -2265.90
# Confusion Matrix:
#  {'human': {'predicted': {'human': 11253, 'bot': 1747}}, 'bot': {'predicted': {'human': 3494, 'bot': 9506}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -384280.00 | Avg: -98.53 | Avg Human: 50.00 | Avg Bot: -172.80
# Average Session Rewards::: Mean: -1280.93 | Human: 650.00 | Bot: -2246.40
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1147, 'bot': 153}}, 'bot': {'predicted': {'human': 698, 'bot': 1902}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -383500.00 | Avg: -98.33 | Avg Human: 50.00 | Avg Bot: -172.50
# Average Session Rewards::: Mean: -1278.33 | Human: 650.00 | Bot: -2242.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2274, 'bot': 326}}, 'bot': {'predicted': {'human': 1309, 'bot': 3891}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -381810.00 | Avg: -97.90 | Avg Human: 50.00 | Avg Bot: -171.85
# Average Session Rewards::: Mean: -1272.70 | Human: 650.00 | Bot: -2234.05
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3349, 'bot': 551}}, 'bot': {'predicted': {'human': 2045, 'bot': 5755}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -379145.00 | Avg: -97.22 | Avg Human: 50.00 | Avg Bot: -170.82
# Average Session Rewards::: Mean: -1263.82 | Human: 650.00 | Bot: -2220.72
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4516, 'bot': 684}}, 'bot': {'predicted': {'human': 2785, 'bot': 7615}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -386165.00 | Avg: -99.02 | Avg Human: 50.00 | Avg Bot: -173.53
# Average Session Rewards::: Mean: -1287.22 | Human: 650.00 | Bot: -2255.82
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5627, 'bot': 873}}, 'bot': {'predicted': {'human': 3464, 'bot': 9536}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -380445.00 | Avg: -97.55 | Avg Human: 50.00 | Avg Bot: -171.32
# Average Session Rewards::: Mean: -1268.15 | Human: 650.00 | Bot: -2227.22
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6773, 'bot': 1027}}, 'bot': {'predicted': {'human': 4185, 'bot': 11415}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -375050.00 | Avg: -96.17 | Avg Human: 50.00 | Avg Bot: -169.25
# Average Session Rewards::: Mean: -1250.17 | Human: 650.00 | Bot: -2200.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7918, 'bot': 1182}}, 'bot': {'predicted': {'human': 4933, 'bot': 13267}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -380900.00 | Avg: -97.67 | Avg Human: 50.00 | Avg Bot: -171.50
# Average Session Rewards::: Mean: -1269.67 | Human: 650.00 | Bot: -2229.50
# Confusion Matrix:
#  {'human': {'predicted': {'human': 9029, 'bot': 1371}}, 'bot': {'predicted': {'human': 5596, 'bot': 15204}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -380250.00 | Avg: -97.50 | Avg Human: 50.00 | Avg Bot: -171.25
# Average Session Rewards::: Mean: -1267.50 | Human: 650.00 | Bot: -2226.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 10137, 'bot': 1563}}, 'bot': {'predicted': {'human': 6261, 'bot': 17139}}}
#
#
#
# Population ::: Human: 100 | Bot: 200
# Final remaining humans: 100
# Final remaining bots: 200
# Total Reward: -382070.00 | Avg: -97.97 | Avg Human: 50.00 | Avg Bot: -171.95
# Average Session Rewards::: Mean: -1273.57 | Human: 650.00 | Bot: -2235.35
# Confusion Matrix:
#  {'human': {'predicted': {'human': 11253, 'bot': 1747}}, 'bot': {'predicted': {'human': 6994, 'bot': 19006}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1054625.00 | Avg: -135.21 | Avg Human: 50.00 | Avg Bot: -172.25
# Average Session Rewards::: Mean: -1757.71 | Human: 650.00 | Bot: -2239.25
# Confusion Matrix:
#  {'human': {'predicted': {'human': 1147, 'bot': 153}}, 'bot': {'predicted': {'human': 1711, 'bot': 4789}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1057160.00 | Avg: -135.53 | Avg Human: 50.00 | Avg Bot: -172.64
# Average Session Rewards::: Mean: -1761.93 | Human: 650.00 | Bot: -2244.32
# Confusion Matrix:
#  {'human': {'predicted': {'human': 2274, 'bot': 326}}, 'bot': {'predicted': {'human': 3442, 'bot': 9558}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1054885.00 | Avg: -135.24 | Avg Human: 50.00 | Avg Bot: -172.29
# Average Session Rewards::: Mean: -1758.14 | Human: 650.00 | Bot: -2239.77
# Confusion Matrix:
#  {'human': {'predicted': {'human': 3349, 'bot': 551}}, 'bot': {'predicted': {'human': 5153, 'bot': 14347}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1053195.00 | Avg: -135.03 | Avg Human: 50.00 | Avg Bot: -172.03
# Average Session Rewards::: Mean: -1755.33 | Human: 650.00 | Bot: -2236.39
# Confusion Matrix:
#  {'human': {'predicted': {'human': 4516, 'bot': 684}}, 'bot': {'predicted': {'human': 7077, 'bot': 18923}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1056510.00 | Avg: -135.45 | Avg Human: 50.00 | Avg Bot: -172.54
# Average Session Rewards::: Mean: -1760.85 | Human: 650.00 | Bot: -2243.02
# Confusion Matrix:
#  {'human': {'predicted': {'human': 5627, 'bot': 873}}, 'bot': {'predicted': {'human': 8867, 'bot': 23633}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1054690.00 | Avg: -135.22 | Avg Human: 50.00 | Avg Bot: -172.26
# Average Session Rewards::: Mean: -1757.82 | Human: 650.00 | Bot: -2239.38
# Confusion Matrix:
#  {'human': {'predicted': {'human': 6773, 'bot': 1027}}, 'bot': {'predicted': {'human': 10622, 'bot': 28378}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1045460.00 | Avg: -134.03 | Avg Human: 50.00 | Avg Bot: -170.84
# Average Session Rewards::: Mean: -1742.43 | Human: 650.00 | Bot: -2220.92
# Confusion Matrix:
#  {'human': {'predicted': {'human': 7918, 'bot': 1182}}, 'bot': {'predicted': {'human': 12333, 'bot': 33167}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1053000.00 | Avg: -135.00 | Avg Human: 50.00 | Avg Bot: -172.00
# Average Session Rewards::: Mean: -1755.00 | Human: 650.00 | Bot: -2236.00
# Confusion Matrix:
#  {'human': {'predicted': {'human': 9029, 'bot': 1371}}, 'bot': {'predicted': {'human': 13953, 'bot': 38047}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# Final remaining humans: 100
# Final remaining bots: 500
# Total Reward: -1049425.00 | Avg: -134.54 | Avg Human: 50.00 | Avg Bot: -171.45
# Average Session Rewards::: Mean: -1749.04 | Human: 650.00 | Bot: -2228.85
# Confusion Matrix:
#  {'human': {'predicted': {'human': 10137, 'bot': 1563}}, 'bot': {'predicted': {'human': 15673, 'bot': 42827}}}
#
#
#
# Population ::: Human: 100 | Bot: 500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 61
#      59 # 1. Perception: Get humanity score
#      60 mouse_data = user.get_step_data()
# ---> 61 h_score = get_humanity_score(mouse_data)
#      63 # Update user's internal tracking
#      64 user.update_stats(h_score) # Logic moved to a helper for cleanliness
#
# Cell In[2], line 17, in get_humanity_score(mouse_movement)
#      14 formatted_movements = [[m['x'], m['y']] for m in mouse_movement]
#      15 try:
#      16     # Assuming scorer is the LSTM model
# ---> 17     prediction = scorer.predict(formatted_movements)
#      18     return float(prediction)
#      19 except Exception as e:
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\offline\scoring_service\HumanityScorer.py:34, in HumanityScorer.predict(self, mouse_movement)
#      32 data = [mouse_movement]
#      33 data = handle_data(data=data, max_length=CONTEXT_LENGTH)   # np.array(data).reshape((-1, 2))
# ---> 34 humanity_scores = self.model.predict(data, verbose=0)
#      35 humanity_scores = [score for [score] in humanity_scores]
#      36 # print(data.shape)
#      37 # print(humanity_scores)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:527, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     522 @traceback_utils.filter_traceback
#     523 def predict(
#     524     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     525 ):
#     526     # Create an iterator that yields batches of input data.
# --> 527     epoch_iterator = TFEpochIterator(
#     528         x=x,
#     529         batch_size=batch_size,
#     530         steps_per_epoch=steps,
#     531         shuffle=False,
#     532         distribute_strategy=self.distribute_strategy,
#     533         steps_per_execution=self.steps_per_execution,
#     534     )
#     536     # Container that configures and calls callbacks.
#     537     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:750, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     748 super().__init__(*args, **kwargs)
#     749 self._distribute_strategy = distribute_strategy
# --> 750 dataset = self.data_adapter.get_tf_dataset()
#     751 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     752     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     753         dataset
#     754     )
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:126, in ArrayDataAdapter.get_tf_dataset(self)
#     113 num_full_batches = int(self._num_samples // batch_size)
#     115 # Vectorized version of shuffle.
#     116 # This is a performance improvement over using `from_tensor_slices`.
#     117 # The indices of the data are shuffled and batched, and these indices
#    (...)    123 # 4. optimized permutation batching
#     124 # 5. disabled static optimizations
# --> 126 indices_dataset = tf.data.Dataset.range(1)
#     128 def permutation(_):
#     129     # It turns out to be more performant to make a new set of indices
#     130     # rather than reusing the same range Tensor. (presumably because of
#     131     # buffer forwarding.)
#     132     indices = tf.range(num_samples, dtype=tf.int64)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1022, in DatasetV2.range(*args, **kwargs)
#    1018 # Loaded lazily due to a circular dependency (dataset_ops -> range_op ->
#    1019 # -> dataset_ops).
#    1020 # pylint: disable=g-import-not-at-top,protected-access
#    1021 from tensorflow.python.data.ops import range_op
# -> 1022 return range_op._range(*args, **kwargs)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\data\ops\range_op.py:25, in _range(*args, **kwargs)
#      24 def _range(*args, **kwargs):  # pylint: disable=unused-private-name
# ---> 25   return _RangeDataset(*args, **kwargs)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\data\ops\range_op.py:35, in _RangeDataset.__init__(self, *args, **kwargs)
#      33 self._parse_args(*args, **kwargs)
#      34 self._structure = tensor_spec.TensorSpec([], self._output_type)
# ---> 35 variant_tensor = gen_dataset_ops.range_dataset(
#      36     start=self._start,
#      37     stop=self._stop,
#      38     step=self._step,
#      39     **self._common_args)
#      40 super().__init__(variant_tensor)
#
# File c:\Users\Sriram Sunderrajan\Projects\Captcha_RL_Project\env\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:6142, in range_dataset(start, stop, step, output_types, output_shapes, metadata, replicate_on_split, name)
#    6140 if tld.is_eager:
#    6141   try:
# -> 6142     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6143       _ctx, "RangeDataset", name, start, stop, step, "output_types",
#    6144       output_types, "output_shapes", output_shapes, "metadata", metadata,
#    6145       "replicate_on_split", replicate_on_split)
#    6146     return _result
#    6147   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# ---- Moving average ----
window_size = 20
moving_avg = []
for i in range(len(HUMAN_REWARD)):
    if i < window_size:
        moving_avg.append(np.mean(HUMAN_REWARD[:i+1]))
    else:
        moving_avg.append(np.mean(HUMAN_REWARD[i-window_size+1:i+1]))

plt.plot(HUMAN_REWARD, color="green")
plt.plot(moving_avg, color="red")
plt.ylim(-200, 100)
plt.show()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))

plt.plot(timestep_counts, human_counts,
         label="Humans",
         linestyle="-",
         linewidth=2)

plt.plot(timestep_counts, bot_counts,
         label="Bots",
         linestyle="--",
         linewidth=2)

plt.xlabel("Timestep")
plt.ylabel("Number of Users")
plt.title("Human vs Bot Population Over Time")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
